# %%
# Import the libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import spacy
from spacy.lang.en.stop_words import STOP_WORDS
import string # Import punc

# %%
# I choose the Yelp text. 
Yelp = pd.read_csv(r"D:\Caroline\Documents\Graduate\ISE 540 Text Analysis\Dataset\NLP Projects\NLP Projects\yelp_labelled_3.txt", sep='\t')
print(Yelp.head(10))
print(Yelp.tail(10))
# Out:
#                                              Message  Review
# 0                           Wow... Loved this place.       1
# 1                                 Crust is not good.       0
# 2          Not tasty and the texture was just nasty.       0
# 3  Stopped by during the late May bank holiday of...       1
# 4  The selection on the menu was great and so wer...       1
# 5     Now I am getting angry and I want my damn pho.       0
# 6              Honeslty it didn't taste THAT fresh.)       0
# 7  The potatoes were like rubber and you could te...       0
# 8                          The fries were great too.       1
# 9                                     A great touch.       1
#                                                Message  Review
# 990  The refried beans that came with my meal were ...       0
# 991         Spend your money and time some place else.       0
# 992  A lady at the table next to us found a live gr...       0
# 993            the presentation of the food was awful.       0
# 994           I can't tell you how disappointed I was.       0
# 995  I think food should have flavor and texture an...       0
# 996                           Appetite instantly gone.       0
# 997  Overall I was not impressed and would not go b...       0
# 998  The whole experience was underwhelming, and I ...       0
# 999  Then, as if I hadn't wasted enough of my life ...       0

# %%
print("Length of the dataset:",len(Yelp))
print(Yelp.isnull().sum())
# Out:
# Length of the dataset: 1000
# Message    0
# Review     0
# dtype: int64

# %%
nlp = spacy.load('en_core_web_sm')
comment = Yelp.iloc[:,0]
print(comment)
# Out:
# 0                               Wow... Loved this place.
# 1                                     Crust is not good.
# 2              Not tasty and the texture was just nasty.
# 3      Stopped by during the late May bank holiday of...
# 4      The selection on the menu was great and so wer...
#                              ...
# 995    I think food should have flavor and texture an...
# 996                             Appetite instantly gone.
# 997    Overall I was not impressed and would not go b...
# 998    The whole experience was underwhelming, and I ...
# 999    Then, as if I hadn't wasted enough of my life ...
# Name: Message, Length: 1000, dtype: object

# %%
# Create the tokens
# Read your data into a pandas Series
Yelp_series = pd.Series(comment)  # Replace 'Your data series' with your actual data
# Convert the Series object to a string
Yelp_text = Yelp_series.str.cat(sep=' ')
# Pass the string to the nlp function
doc = nlp(Yelp_text)
for token in doc:
    print(token.text, token.pos_, token.dep_)
# Out:
# Wow INTJ ROOT
# ... PUNCT punct
# Loved VERB ROOT
# this DET det
# place NOUN dobj
# . PUNCT punct
# Crust NOUN nsubj
# is AUX ROOT
# not PART neg
# good ADJ acomp
# . PUNCT punct
# Not PART neg
# tasty ADJ ROOT
# and CCONJ cc
# the DET det
# texture NOUN nsubj
# was AUX conj
# just ADV advmod
# nasty ADJ acomp
# . PUNCT punct
# Stopped VERB ROOT
# by ADP prt
# during ADP prep
# the DET det
# late ADJ amod
# May PROPN compound
# bank NOUN compound
# holiday NOUN pobj
# off ADP prep
# Rick PROPN compound
# Steve PROPN compound
# recommendation NOUN pobj
# and CCONJ cc
# loved VERB conj
# it PRON dobj
# . PUNCT punct
# The DET det
# selection NOUN nsubj
# on ADP prep
# the DET det
# menu NOUN pobj
# was AUX ROOT
# great ADJ acomp
# and CCONJ cc
# so ADV advmod
# were AUX conj
# the DET det
# prices NOUN nsubj
# . PUNCT punct
# Now ADV advmod
# I PRON nsubj
# am AUX aux
# getting VERB ROOT
# angry ADJ acomp
# and CCONJ cc
# I PRON nsubj
# want VERB conj
# my PRON poss
# damn ADJ amod
# pho NOUN dobj
# . PUNCT punct
# Honeslty NOUN npadvmod
# it PRON nsubj
# did AUX aux
# n't PART neg
# taste VERB ROOT
# THAT PRON dobj
# fresh ADJ acomp
# . PUNCT punct
# ) PUNCT punct
# The DET det
# potatoes NOUN nsubj
# were AUX ROOT
# like ADP prep
# rubber NOUN pobj
# and CCONJ cc
# you PRON nsubj
# could AUX aux
# tell VERB conj
# they PRON nsubjpass
# had AUX aux
# been AUX auxpass
# made VERB ccomp
# up ADP prt
# ahead ADV advmod
# of ADP prep
# time NOUN nsubjpass
# being AUX auxpass
# kept VERB ccomp
# under ADP prep
# a DET det
# warmer NOUN pobj
# . PUNCT punct
# The DET det
# fries NOUN nsubj
# were AUX ROOT
# great ADJ acomp
# too ADV advmod
# . PUNCT punct
# A DET det
# great ADJ amod
# touch NOUN ROOT
# . PUNCT punct
# Service NOUN nsubj
# was AUX ROOT
# very ADV advmod
# prompt ADJ acomp
# . PUNCT punct
# Would AUX aux
# not PART neg
# go VERB ROOT
# back ADV advmod
# . PUNCT punct
# The DET det
# cashier NOUN nsubj
# had VERB ROOT
# no DET det
# care NOUN dobj
# what PRON dobj
# so ADV advmod
# ever ADV advmod
# on ADP prep
# what PRON dobj
# I PRON nsubj
# had AUX pcomp
# to PART aux
# say VERB xcomp
# it PRON nsubj
# still ADV advmod
# ended VERB ccomp
# up ADP prt
# being AUX auxpass
# wayyy VERB acomp
# overpriced ADJ advcl
# . PUNCT punct
# I PRON nsubj
# tried VERB ROOT
# the DET det
# Cape PROPN compound
# Cod PROPN compound
# ravoli NOUN dobj
# , PUNCT punct
# chicken NOUN appos
# , PUNCT punct
# with ADP prep
# cranberry PROPN pobj
# ... PUNCT punct
# mmmm PROPN appos
# ! PUNCT punct
# I PRON nsubj
# was AUX ROOT
# disgusted ADJ acomp
# because SCONJ mark
# I PRON nsubj
# was AUX advcl
# pretty ADV advmod
# sure ADJ acomp
# that PRON nsubj
# was AUX ccomp
# human ADJ amod
# hair NOUN attr
# . PUNCT punct
# I PRON nsubj
# was AUX ROOT
# shocked ADJ acomp
# because SCONJ mark
# no DET det
# signs NOUN nsubj
# indicate VERB advcl
# cash NOUN dobj
# only ADV advmod
# . PUNCT punct
# Highly ADV advmod
# recommended VERB ROOT
# . PUNCT punct
# Waitress NOUN nsubj
# was AUX ROOT
# a DET det
# little ADJ amod
# slow NOUN attr
# in ADP prep
# service NOUN pobj
# . PUNCT punct
# This DET det
# place NOUN nsubj
# is AUX ROOT
# not PART neg
# worth ADJ acomp
# your PRON poss
# time NOUN npadvmod
# , PUNCT punct
# let VERB dep
# alone ADV advmod
# Vegas PROPN npadvmod
# . PUNCT punct
# did AUX aux
# not PART neg
# like VERB ROOT
# at ADV advmod
# all ADV advmod
# . PUNCT punct
# The DET det
# Burrittos PROPN compound
# Blah PROPN ROOT
# ! PUNCT punct
# The DET det
# food NOUN ROOT
# , PUNCT punct
# amazing ADJ amod
# . PUNCT punct
# Service NOUN nsubj
# is AUX ROOT
# also ADV advmod
# cute ADJ acomp
# . PUNCT punct
# I PRON nsubj
# could AUX aux
# care VERB ROOT
# less ADV advmod
# ... PUNCT punct
# The DET det
# interior NOUN nsubj
# is AUX ROOT
# just ADV advmod
# beautiful ADJ acomp
# . PUNCT punct
# So ADV advmod
# they PRON nsubj
# performed VERB ROOT
# . PUNCT punct
# That PRON nsubj
# 's AUX ROOT
# right ADJ acomp
# .... PUNCT punct
# the DET det
# red PROPN compound
# velvet NOUN compound
# cake NOUN nsubj
# ..... PUNCT punct
# ohhh ADJ meta
# this DET det
# stuff NOUN nsubj
# is AUX ROOT
# so ADV advmod
# good ADJ acomp
# . PUNCT punct
# - PUNCT punct
# They PRON nsubj
# never ADV neg
# brought VERB ROOT
# a DET det
# salad NOUN dobj
# we PRON nsubj
# asked VERB relcl
# for ADP prep
# . PUNCT punct
# This DET det
# hole NOUN nsubj
# in ADP prep
# the DET det
# wall NOUN pobj
# has VERB ROOT
# great ADJ amod
# Mexican ADJ amod
# street NOUN compound
# tacos NOUN dobj
# , PUNCT punct
# and CCONJ cc
# friendly ADJ amod
# staff NOUN conj
# . PUNCT punct
# Took VERB advcl
# an DET det
# hour NOUN dobj
# to PART aux
# get VERB advcl
# our PRON poss
# food NOUN dobj
# only ADV advmod
# 4 NUM nummod
# tables NOUN npadvmod
# in ADP prep
# restaurant NOUN pobj
# my PRON poss
# food NOUN nsubj
# was AUX ccomp
# Luke PROPN npadvmod
# warm ADJ acomp
# , PUNCT punct
# Our PRON poss
# sever NOUN nsubj
# was AUX aux
# running VERB ROOT
# around ADV advmod
# like SCONJ mark
# he PRON nsubj
# was AUX advcl
# totally ADV advmod
# overwhelmed ADJ acomp
# . PUNCT punct
# The DET det
# worst ADJ nsubj
# was AUX ROOT
# the DET det
# salmon NOUN compound
# sashimi NOUN attr
# . PUNCT punct
# Also ADV advmod
# there PRON expl
# are VERB ROOT
# combos NOUN attr
# like ADP prep
# a DET det
# burger NOUN pobj
# , PUNCT punct
# fries NOUN conj
# , PUNCT punct
# and CCONJ cc
# beer NOUN conj
# for ADP prep
# 23 NUM pobj
# which PRON nsubj
# is AUX relcl
# a DET det
# decent ADJ amod
# deal NOUN attr
# . PUNCT punct
# This PRON nsubj
# was AUX ROOT
# like ADP prep
# the DET det
# final ADJ amod
# blow NOUN pobj
# ! PUNCT punct
# I PRON nsubj
# found VERB ROOT
# this DET det
# place NOUN dobj
# by ADP prep
# accident NOUN pobj
# and CCONJ cc
# I PRON nsubj
# could AUX aux
# not PART neg
# be AUX conj
# happier ADJ acomp
# . PUNCT punct
# seems VERB ROOT
# like ADP prep
# a DET det
# good ADJ amod
# quick ADJ amod
# place NOUN pobj
# to PART aux
# grab VERB relcl
# a DET det
# bite NOUN dobj
# of ADP prep
# some DET det
# familiar ADJ amod
# pub NOUN compound
# food NOUN pobj
# , PUNCT punct
# but CCONJ cc
# do VERB conj
# yourself PRON dative
# a DET det
# favor NOUN dobj
# and CCONJ cc
# look VERB conj
# elsewhere ADV advmod
# . PUNCT punct
# Overall ADV advmod
# , PUNCT punct
# I PRON nsubj
# like VERB ROOT
# this DET det
# place NOUN dobj
# a DET det
# lot NOUN npadvmod
# . PUNCT punct
# The DET det
# only ADJ advmod
# redeeming VERB amod
# quality NOUN nsubj
# of ADP prep
# the DET det
# restaurant NOUN pobj
# was AUX ROOT
# that SCONJ mark
# it PRON nsubj
# was AUX ccomp
# very ADV advmod
# inexpensive ADJ acomp
# . PUNCT punct
# Ample ADJ amod
# portions NOUN ROOT
# and CCONJ cc
# good ADJ amod
# prices NOUN conj
# . PUNCT punct
# Poor ADJ amod
# service NOUN nsubj
# , PUNCT punct
# the DET det
# waiter NOUN nsubj
# made VERB ROOT
# me PRON nsubj
# feel VERB ccomp
# like SCONJ mark
# I PRON nsubj
# was AUX advcl
# stupid ADJ acomp
# every DET det
# time NOUN npadvmod
# he PRON nsubj
# came VERB relcl
# to ADP prep
# the DET det
# table NOUN pobj
# . PUNCT punct
# My PRON poss
# first ADJ amod
# visit NOUN nsubj
# to ADP prep
# Hiro PROPN pobj
# was AUX ROOT
# a DET det
# delight NOUN attr
# ! PUNCT punct
# Service NOUN nsubj
# sucks VERB ROOT
# . PUNCT punct
# The DET det
# shrimp NOUN compound
# tender NOUN ROOT
# and CCONJ cc
# moist NOUN conj
# . PUNCT punct
# There PRON expl
# is VERB ROOT
# not PART neg
# a DET det
# deal NOUN attr
# good ADJ amod
# enough ADV advmod
# that PRON nsubj
# would AUX aux
# drag VERB relcl
# me PRON dobj
# into ADP prep
# that DET det
# establishment NOUN pobj
# again ADV advmod
# . PUNCT punct
# Hard ADV ROOT
# to PART aux
# judge VERB xcomp
# whether SCONJ mark
# these DET det
# sides NOUN nsubj
# were AUX ccomp
# good ADJ acomp
# because SCONJ mark
# we PRON nsubjpass
# were AUX auxpass
# grossed VERB advcl
# out ADP prt
# by ADP agent
# the DET det
# melted VERB amod
# styrofoam NOUN pobj
# and CCONJ cc
# did AUX aux
# n't PART neg
# want VERB conj
# to PART aux
# eat VERB xcomp
# it PRON dobj
# for ADP prep
# fear NOUN pobj
# of ADP prep
# getting VERB pcomp
# sick ADJ acomp
# . PUNCT punct
# On ADP prep
# a DET det
# positive ADJ amod
# note NOUN pobj
# , PUNCT punct
# our PRON poss
# server NOUN nsubj
# was AUX ROOT
# very ADV advmod
# attentive ADJ acomp
# and CCONJ cc
# provided VERB conj
# great ADJ amod
# service NOUN dobj
# . PUNCT punct
# Frozen ADJ amod
# pucks NOUN ROOT
# of ADP prep
# disgust NOUN pobj
# , PUNCT punct
# with ADP prep
# some PRON pobj
# of ADP prep
# the DET det
# worst ADJ amod
# people NOUN pobj
# behind ADP prep
# the DET det
# register NOUN pobj
# . PUNCT punct
# The DET det
# only ADJ amod
# thing NOUN nsubj
# I PRON nsubj
# did VERB relcl
# like INTJ intj
# was AUX ROOT
# the DET det
# prime ADJ amod
# rib NOUN attr
# and CCONJ cc
# dessert NOUN compound
# section NOUN conj
# . PUNCT punct
# It PRON nsubj
# 's AUX ROOT
# too ADV advmod
# bad ADJ acomp
# the DET det
# food NOUN nsubj
# is AUX ccomp
# so ADV advmod
# damn ADV advmod
# generic ADJ acomp
# . PUNCT punct
# The DET det
# burger NOUN nsubj
# is AUX ROOT
# good ADJ amod
# beef NOUN attr
# , PUNCT punct
# cooked VERB advcl
# just ADV advmod
# right ADV advmod
# . PUNCT punct
# If SCONJ mark
# you PRON nsubj
# want VERB advcl
# a DET det
# sandwich NOUN nsubj
# just ADV advmod
# go VERB ROOT
# to ADP prep
# any DET det
# Firehouse PROPN pobj
# ! PUNCT punct
# ! PUNCT punct
# ! PUNCT punct
# ! PUNCT punct
# ! PUNCT punct
# My PRON poss
# side NOUN nsubj
# Greek PROPN appos
# salad NOUN nsubj
# with ADP prep
# the DET det
# Greek PROPN amod
# dressing NOUN pobj
# was AUX ROOT
# so ADV advmod
# tasty ADJ acomp
# , PUNCT punct
# and CCONJ cc
# the DET det
# pita NOUN nsubj
# and CCONJ cc
# hummus NOUN conj
# was AUX conj
# very ADV advmod
# refreshing ADJ acomp
# . PUNCT punct
# We PRON nsubj
# ordered VERB ROOT
# the DET det
# duck NOUN compound
# rare ADJ dobj
# and CCONJ cc
# it PRON nsubj
# was AUX conj
# pink ADJ acomp
# and CCONJ cc
# tender ADJ conj
# on ADP prep
# the DET det
# inside NOUN pobj
# with ADP prep
# a DET det
# nice ADJ amod
# char NOUN pobj
# on ADP prep
# the DET det
# outside NOUN pobj
# . PUNCT punct
# He PRON nsubj
# came VERB ROOT
# running VERB advcl
# after ADP prep
# us PRON pobj
# when SCONJ advmod
# he PRON nsubj
# realized VERB advcl
# my PRON poss
# husband NOUN nsubj
# had AUX aux
# left VERB ccomp
# his PRON poss
# sunglasses NOUN dobj
# on ADP prep
# the DET det
# table NOUN pobj
# . PUNCT punct
# Their PRON poss
# chow NOUN compound
# mein NOUN nsubj
# is AUX ROOT
# so ADV advmod
# good ADJ acomp
# ! PUNCT punct
# They PRON nsubj
# have VERB ROOT
# horrible ADJ amod
# attitudes NOUN dobj
# towards ADP prep
# customers NOUN pobj
# , PUNCT punct
# and CCONJ cc
# talk VERB conj
# down ADP prt
# to ADP prep
# each DET det
# one NOUN pobj
# when SCONJ advmod
# customers NOUN nsubj
# do AUX aux
# n't PART neg
# enjoy VERB advcl
# their PRON poss
# food NOUN dobj
# . PUNCT punct
# The DET det
# portion NOUN nsubj
# was AUX ROOT
# huge ADJ acomp
# ! PUNCT punct
# Loved VERB ROOT
# it PRON dobj
# ... PUNCT punct
# friendly ADJ amod
# servers NOUN dobj
# , PUNCT punct
# great ADJ amod
# food NOUN nmod
# , PUNCT punct
# wonderful ADJ amod
# and CCONJ cc
# imaginative ADJ conj
# menu NOUN appos
# . PUNCT punct
# The DET det
# Heart PROPN compound
# Attack PROPN compound
# Grill PROPN nsubj
# in ADP prep
# downtown NOUN compound
# Vegas PROPN pobj
# is AUX ROOT
# an DET det
# absolutely ADV advmod
# flat ADV advmod
# - PUNCT punct
# lined VERB amod
# excuse NOUN attr
# for ADP prep
# a DET det
# restaurant NOUN pobj
# . PUNCT punct
# Not PART neg
# much ADJ amod
# seafood NOUN ROOT
# and CCONJ cc
# like ADP conj
# 5 NUM nummod
# strings NOUN pobj
# of ADP prep
# pasta NOUN pobj
# at ADP prep
# the DET det
# bottom NOUN pobj
# . PUNCT punct
# The DET det
# salad NOUN nsubj
# had VERB ROOT
# just ADV advmod
# the DET det
# right ADJ amod
# amount NOUN dobj
# of ADP prep
# sauce NOUN pobj
# to ADP prep
# not PART neg
# over ADP prep
# power NOUN pobj
# the DET det
# scallop NOUN dobj
# , PUNCT punct
# which PRON nsubjpass
# was AUX auxpass
# perfectly ADV advmod
# cooked VERB relcl
# . PUNCT punct
# The DET det
# ripped VERB amod
# banana NOUN nsubjpass
# was AUX auxpass
# not PART preconj
# only ADV advmod
# ripped VERB ROOT
# , PUNCT punct
# but CCONJ cc
# petrified ADJ conj
# and CCONJ cc
# tasteless ADJ conj
# . PUNCT punct
# At ADP advmod
# least ADJ advmod
# think VERB ROOT
# to PART aux
# refill VERB xcomp
# my PRON poss
# water NOUN dobj
# before SCONJ mark
# I PRON nsubj
# struggle VERB advcl
# to PART aux
# wave VERB xcomp
# you PRON dobj
# over ADP prt
# for ADP prep
# 10 NUM nummod
# minutes NOUN pobj
# . PUNCT punct
# This DET det
# place NOUN nsubj
# receives VERB ROOT
# stars NOUN dobj
# for ADP prep
# their PRON poss
# APPETIZERS NOUN pobj
# ! PUNCT punct
# ! PUNCT punct
# ! PUNCT punct
# The DET det
# cocktails NOUN nsubj
# are AUX ROOT
# all ADV dep
# handmade ADJ acomp
# and CCONJ cc
# delicious ADJ conj
# . PUNCT punct
# We PRON nsubj
# 'd AUX aux
# definitely ADV advmod
# go VERB ROOT
# back ADV advmod
# here ADV advmod
# again ADV advmod
# . PUNCT punct
# We PRON nsubj
# are AUX ROOT
# so ADV advmod
# glad ADJ acomp
# we PRON nsubj
# found VERB ccomp
# this DET det
# place NOUN dobj
# . PUNCT punct
# Great ADJ amod
# food NOUN ROOT
# and CCONJ cc
# service NOUN conj
# , PUNCT punct
# huge ADJ amod
# portions NOUN conj
# and CCONJ cc
# they PRON nsubj
# give VERB conj
# a DET det
# military ADJ amod
# discount NOUN dobj
# . PUNCT punct
# Always ADV advmod
# a DET det
# great ADJ amod
# time NOUN ROOT
# at ADP prep
# Dos PROPN compound
# Gringos PROPN pobj
# ! PUNCT punct
# Update NOUN nsubj
# ..... PUNCT punct
# went VERB ROOT
# back ADV advmod
# for ADP prep
# a DET det
# second ADJ amod
# time NOUN pobj
# and CCONJ cc
# it PRON nsubj
# was AUX conj
# still ADV advmod
# just ADV advmod
# as ADV advmod
# amazing ADJ advcl
# We PRON nsubj
# got VERB ccomp
# the DET det
# food NOUN dobj
# and CCONJ cc
# apparently ADV advmod
# they PRON nsubj
# have AUX aux
# never ADV neg
# heard VERB conj
# of ADP prep
# salt NOUN pobj
# and CCONJ cc
# the DET det
# batter NOUN nsubj
# on ADP prep
# the DET det
# fish NOUN pobj
# was AUX conj
# chewy NOUN attr
# . PUNCT punct
# A DET det
# great ADJ amod
# way NOUN ROOT
# to PART aux
# finish VERB relcl
# a DET det
# great ADJ dobj
# . PUNCT punct
# The DET det
# deal NOUN nsubj
# included VERB ROOT
# 5 NUM nummod
# tastings NOUN dobj
# and CCONJ cc
# 2 NUM nummod
# drinks NOUN conj
# , PUNCT punct
# and CCONJ cc
# Jeff PROPN nsubj
# went VERB conj
# above ADV advmod
# and CCONJ cc
# beyond ADP conj
# what PRON dobj
# we PRON nsubj
# expected VERB pcomp
# . PUNCT punct
# - PUNCT punct
# Really ADV advmod
# , PUNCT punct
# really ADV advmod
# good ADJ amod
# rice NOUN ROOT
# , PUNCT punct
# all DET predet
# the DET det
# time NOUN npadvmod
# . PUNCT punct
# The DET det
# service NOUN nsubj
# was AUX ROOT
# meh NOUN acomp
# . PUNCT punct
# It PRON nsubj
# took VERB ROOT
# over ADP quantmod
# 30 NUM nummod
# min NOUN dobj
# to PART aux
# get VERB xcomp
# their PRON poss
# milkshake NOUN dobj
# , PUNCT punct
# which PRON nsubj
# was AUX relcl
# nothing PRON attr
# more ADJ amod
# than ADP prep
# chocolate NOUN compound
# milk NOUN pobj
# . PUNCT punct
# I PRON nsubj
# guess VERB ROOT
# I PRON nsubj
# should AUX aux
# have AUX aux
# known VERB ccomp
# that SCONJ mark
# this DET det
# place NOUN nsubj
# would AUX aux
# suck VERB ccomp
# , PUNCT punct
# because SCONJ mark
# it PRON nsubj
# is AUX advcl
# inside ADV prep
# of ADP prep
# the DET det
# Excalibur PROPN pobj
# , PUNCT punct
# but CCONJ cc
# I PRON nsubj
# did AUX aux
# n't PART neg
# use VERB conj
# my PRON poss
# common ADJ amod
# sense NOUN dobj
# . PUNCT punct
# The DET det
# scallop ADJ amod
# dish NOUN nsubj
# is AUX ROOT
# quite ADV advmod
# appalling ADJ acomp
# for ADP prep
# value NOUN pobj
# as ADV advmod
# well ADV advmod
# . PUNCT punct
# 2 NUM nummod
# times NOUN ROOT
# - PUNCT punct
# Very ADV advmod
# Bad PROPN compound
# Customer PROPN compound
# Service PROPN appos
# ! PUNCT punct
# The DET det
# sweet ADJ amod
# potato NOUN compound
# fries NOUN nsubj
# were AUX ROOT
# very ADV advmod
# good ADJ acomp
# and CCONJ cc
# seasoned VERB conj
# well ADV advmod
# . PUNCT punct
# Today NOUN nsubj
# is AUX ROOT
# the DET det
# second ADJ amod
# time NOUN attr
# I PRON nsubj
# 've AUX aux
# been AUX relcl
# to ADP prep
# their PRON poss
# lunch NOUN compound
# buffet NOUN pobj
# and CCONJ cc
# it PRON nsubj
# was AUX conj
# pretty ADV advmod
# good ADJ acomp
# . PUNCT punct
# There PRON expl
# is VERB ROOT
# so ADV advmod
# much ADV amod
# good ADJ amod
# food NOUN attr
# in ADP prep
# Vegas PROPN pobj
# that SCONJ mark
# I PRON nsubj
# feel VERB ccomp
# cheated VERB acomp
# for ADP prep
# wasting VERB pcomp
# an DET det
# eating VERB amod
# opportunity NOUN dobj
# by ADP prep
# going VERB pcomp
# to ADP prep
# Rice PROPN pobj
# and CCONJ cc
# Company PROPN conj
# . PUNCT punct
# Coming VERB csubj
# here ADV advmod
# is AUX ROOT
# like ADP prep
# experiencing VERB pcomp
# an DET det
# underwhelming ADJ amod
# relationship NOUN dobj
# where SCONJ advmod
# both DET det
# parties NOUN nsubj
# ca AUX aux
# n't PART neg
# wait VERB relcl
# for SCONJ mark
# the DET det
# other ADJ amod
# person NOUN nsubj
# to PART aux
# ask VERB advcl
# to PART aux
# break VERB xcomp
# up ADP prt
# . PUNCT punct
# walked VERB ROOT
# in ADV advmod
# and CCONJ cc
# the DET det
# place NOUN nsubj
# smelled VERB conj
# like ADP prep
# an DET det
# old ADJ amod
# grease NOUN compound
# trap NOUN pobj
# and CCONJ cc
# only ADV advmod
# 2 NUM nummod
# others NOUN conj
# there ADV advmod
# eating VERB acl
# . PUNCT punct
# The DET det
# turkey NOUN nsubj
# and CCONJ cc
# roast NOUN compound
# beef NOUN conj
# were AUX ROOT
# bland ADJ acomp
# . PUNCT punct
# This DET det
# place NOUN nsubj
# has VERB ROOT
# it PRON dobj
# ! PUNCT punct
# The DET det
# pan NOUN compound
# cakes VERB ROOT
# everyone PRON nsubj
# are AUX aux
# raving VERB ccomp
# about ADP prep
# taste NOUN pobj
# like ADP prep
# a DET det
# sugary ADJ amod
# disaster NOUN pobj
# tailored VERB acl
# to ADP prep
# the DET det
# palate NOUN pobj
# of ADP prep
# a DET det
# six NUM nummod
# year NOUN npadvmod
# old ADJ pobj
# . PUNCT punct
# I PRON nsubj
# love VERB ROOT
# the DET det
# Pho PROPN dobj
# and CCONJ cc
# the DET det
# spring NOUN compound
# rolls NOUN conj
# oh INTJ intj
# so ADV advmod
# yummy INTJ intj
# you PRON nsubj
# have VERB ROOT
# to PART aux
# try VERB xcomp
# . PUNCT punct
# The DET det
# poor ADJ amod
# batter NOUN nsubj
# to PART aux
# meat NOUN compound
# ratio NOUN appos
# made VERB ROOT
# the DET det
# chicken NOUN nsubj
# tenders NOUN ccomp
# very ADV advmod
# unsatisfying ADJ oprd
# . PUNCT punct
# All PRON nsubj
# I PRON nsubj
# have VERB relcl
# to PART aux
# say VERB xcomp
# is AUX ROOT
# the DET det
# food NOUN nsubj
# was AUX ccomp
# amazing ADJ acomp
# ! PUNCT punct
# ! PUNCT punct
# ! PUNCT punct
# Omelets NOUN nsubj
# are AUX ROOT
# to PART aux
# die VERB xcomp
# for ADP prep
# ! PUNCT punct
# Everything PRON nsubj
# was AUX ROOT
# fresh ADJ acomp
# and CCONJ cc
# delicious ADJ conj
# ! PUNCT punct
# In ADP prep
# summary NOUN pobj
# , PUNCT punct
# this PRON nsubj
# was AUX ROOT
# a DET det
# largely ADV advmod
# disappointing ADJ amod
# dining NOUN compound
# experience NOUN attr
# . PUNCT punct
# It PRON nsubj
# 's AUX ROOT
# like ADP prep
# a DET det
# really ADV advmod
# sexy ADJ amod
# party NOUN pobj
# in ADP prep
# your PRON poss
# mouth NOUN pobj
# , PUNCT punct
# where SCONJ advmod
# you PRON nsubj
# 're AUX aux
# outrageously ADV advmod
# flirting VERB relcl
# with ADP prep
# the DET det
# hottest ADJ amod
# person NOUN pobj
# at ADP prep
# the DET det
# party NOUN pobj
# . PUNCT punct
# Never ADV neg
# been AUX advcl
# to ADP prep
# Hard PROPN compound
# Rock PROPN compound
# Casino PROPN pobj
# before ADV advmod
# , PUNCT punct
# WILL AUX aux
# NEVER ADV neg
# EVER ADV advmod
# STEP VERB ROOT
# FORWARD ADV dobj
# IN ADP prep
# IT NOUN pobj
# AGAIN ADV advmod
# ! PUNCT punct
# Best ADJ amod
# breakfast NOUN compound
# buffet NOUN ROOT
# ! PUNCT punct
# ! PUNCT punct
# ! PUNCT punct
# say VERB ROOT
# bye INTJ intj
# bye INTJ intj
# to ADP prep
# your PRON poss
# tip NOUN compound
# lady NOUN pobj
# ! PUNCT punct
# We PRON nsubj
# 'll AUX aux
# never ADV neg
# go VERB ROOT
# again ADV advmod
# . PUNCT punct
# Will AUX aux
# be AUX ROOT
# back ADV advmod
# again ADV advmod
# ! PUNCT punct
# Food NOUN nsubj
# arrived VERB ROOT
# quickly ADV advmod
# ! PUNCT punct
# It PRON nsubj
# was AUX ROOT
# not PART neg
# good ADJ acomp
# . PUNCT punct
# On ADP prep
# the DET det
# up ADJ amod
# side NOUN pobj
# , PUNCT punct
# their PRON poss
# cafe NOUN nsubj
# serves VERB ROOT
# really ADV advmod
# good ADJ amod
# food NOUN dobj
# . PUNCT punct
# Our PRON poss
# server NOUN nsubj
# was AUX ROOT
# fantastic ADJ acomp
# and CCONJ cc
# when SCONJ advmod
# he PRON nsubj
# found VERB advcl
# out ADP prt
# the DET det
# wife NOUN nsubj
# loves VERB ccomp
# roasted ADJ amod
# garlic NOUN dobj
# and CCONJ cc
# bone NOUN compound
# marrow NOUN conj
# , PUNCT punct
# he PRON nsubj
# added VERB conj
# extra ADJ advmod
# to ADP prep
# our PRON poss
# meal NOUN pobj
# and CCONJ cc
# another DET det
# marrow NOUN conj
# to PART aux
# go VERB xcomp
# ! PUNCT punct
# The DET det
# only ADJ amod
# good ADJ amod
# thing NOUN nsubj
# was AUX ccomp
# our PRON poss
# waiter NOUN attr
# , PUNCT punct
# he PRON nsubj
# was AUX ROOT
# very ADV advmod
# helpful ADJ acomp
# and CCONJ cc
# kept VERB conj
# the DET det
# bloddy PROPN compound
# mary PROPN poss
# 's PART case
# coming VERB dobj
# . PUNCT punct
# Best ADJ compound
# Buffet PROPN ROOT
# in ADP prep
# town NOUN pobj
# , PUNCT punct
# for ADP prep
# the DET det
# price NOUN pobj
# you PRON nsubj
# can AUX aux
# not PART neg
# beat VERB relcl
# it PRON dobj
# . PUNCT punct
# I PRON nsubj
# LOVED VERB ccomp
# their PRON poss
# mussels NOUN nsubj
# cooked VERB ccomp
# in ADP prep
# this DET det
# wine NOUN compound
# reduction NOUN pobj
# , PUNCT punct
# the DET det
# duck NOUN nsubj
# was AUX ROOT
# tender ADJ acomp
# , PUNCT punct
# and CCONJ cc
# their PRON poss
# potato NOUN compound
# dishes NOUN nsubj
# were AUX conj
# delicious ADJ acomp
# . PUNCT punct
# This PRON nsubj
# is AUX ROOT
# one NUM attr
# of ADP prep
# the DET det
# better ADJ amod
# buffets NOUN pobj
# that PRON pobj
# I PRON nsubj
# have AUX aux
# been AUX relcl
# to PART prep
# . PUNCT punct
# So ADV advmod
# we PRON nsubj
# went VERB ROOT
# to ADP prep
# Tigerlilly PROPN pobj
# and CCONJ cc
# had VERB conj
# a DET det
# fantastic ADJ amod
# afternoon NOUN dobj
# ! PUNCT punct
# The DET det
# food NOUN nsubj
# was AUX ccomp
# delicious ADJ acomp
# , PUNCT punct
# our PRON poss
# bartender NOUN nsubj
# was AUX ROOT
# attentive ADJ acomp
# and CCONJ cc
# personable ADJ conj
# AND CCONJ cc
# we PRON nsubj
# got VERB conj
# a DET det
# great ADJ amod
# deal NOUN dobj
# ! PUNCT punct
# The DET det
# ambience NOUN nsubj
# is AUX ROOT
# wonderful ADJ acomp
# and CCONJ cc
# there PRON expl
# is VERB conj
# music NOUN compound
# playing VERB attr
# . PUNCT punct
# Will AUX aux
# go VERB ROOT
# back ADV advmod
# next ADJ amod
# trip NOUN dobj
# out ADP advmod
# . PUNCT punct
# Sooooo PROPN nsubj
# good NOUN ROOT
# ! PUNCT punct
# ! PUNCT punct
# REAL PROPN compound
# sushi PROPN compound
# lovers NOUN nsubj
# , PUNCT punct
# let VERB ccomp
# 's PRON nsubj
# be AUX ccomp
# honest ADJ acomp
# - PUNCT punct
# Yama PROPN nsubj
# is AUX ROOT
# not PART neg
# that ADV advmod
# good ADJ acomp
# . PUNCT punct
# At ADP advmod
# least ADJ advmod
# 40min NOUN nsubj
# passed VERB ROOT
# in ADP prt
# between ADP prep
# us PRON compound
# ordering NOUN pobj
# and CCONJ cc
# the DET det
# food NOUN nsubj
# arriving VERB conj
# , PUNCT punct
# and CCONJ cc
# it PRON nsubj
# was AUX conj
# n't PART neg
# that ADV advmod
# busy ADJ acomp
# . PUNCT punct
# This PRON nsubj
# is AUX ROOT
# a DET det
# really ADV advmod
# fantastic ADJ amod
# Thai PROPN compound
# restaurant NOUN attr
# which PRON nsubj
# is AUX relcl
# definitely ADV advmod
# worth ADJ acomp
# a DET det
# visit NOUN npadvmod
# . PUNCT punct
# Nice ADJ ROOT
# , PUNCT punct
# spicy ADJ conj
# and CCONJ cc
# tender NOUN conj
# . PUNCT punct
# Good ADJ amod
# prices NOUN ROOT
# . PUNCT punct
# Check VERB ROOT
# it PRON dobj
# out ADP prt
# . PUNCT punct
# It PRON nsubj
# was AUX ROOT
# pretty ADV advmod
# gross ADJ acomp
# ! PUNCT punct
# I PRON nsubj
# 've AUX aux
# had VERB ROOT
# better ADJ amod
# atmosphere NOUN dobj
# . PUNCT punct
# Kind ADV advmod
# of ADV advmod
# hard ADJ ROOT
# to PART aux
# mess VERB xcomp
# up ADP prt
# a DET det
# steak NOUN dobj
# but CCONJ cc
# they PRON nsubj
# did VERB ROOT
# . PUNCT punct
# Although SCONJ mark
# I PRON nsubj
# very ADV advmod
# much ADV advmod
# liked VERB advcl
# the DET det
# look NOUN dobj
# and CCONJ cc
# sound NOUN conj
# of ADP prep
# this DET det
# place NOUN pobj
# , PUNCT punct
# the DET det
# actual ADJ amod
# experience NOUN nsubj
# was AUX ROOT
# a DET det
# bit NOUN npadvmod
# disappointing ADJ acomp
# . PUNCT punct
# I PRON nsubj
# just ADV advmod
# do AUX aux
# n't PART neg
# know VERB ROOT
# how SCONJ advmod
# this DET det
# place NOUN nsubj
# managed VERB ccomp
# to PART aux
# served VERB xcomp
# the DET det
# blandest ADJ amod
# food NOUN dobj
# I PRON nsubj
# have AUX aux
# ever ADV advmod
# eaten VERB relcl
# when SCONJ advmod
# they PRON nsubj
# are AUX aux
# preparing VERB advcl
# Indian ADJ amod
# cuisine NOUN dobj
# . PUNCT punct
# Worst ADJ amod
# service NOUN ROOT
# to ADP prep
# boot NOUN pobj
# , PUNCT punct
# but CCONJ cc
# that PRON nsubj
# is AUX conj
# the DET det
# least ADJ attr
# of ADP prep
# their PRON poss
# worries NOUN pobj
# . PUNCT punct
# Service NOUN nsubj
# was AUX ROOT
# fine ADJ acomp
# and CCONJ cc
# the DET det
# waitress NOUN nsubj
# was AUX conj
# friendly ADJ acomp
# . PUNCT punct
# The DET det
# guys NOUN nsubj
# all PRON appos
# had VERB ROOT
# steaks NOUN dobj
# , PUNCT punct
# and CCONJ cc
# our PRON poss
# steak NOUN nsubj
# loving VERB amod
# son NOUN appos
# who PRON nsubj
# has AUX aux
# had VERB relcl
# steak NOUN dobj
# at ADP prep
# the DET det
# best ADJ amod
# and CCONJ cc
# worst ADJ conj
# places NOUN pobj
# said VERB conj
# it PRON nsubj
# was AUX ccomp
# the DET det
# best ADJ amod
# steak NOUN attr
# he PRON nsubjpass
# 's AUX auxpass
# ever ADV advmod
# eaten VERB relcl
# . PUNCT punct
# We PRON nsubj
# thought VERB ROOT
# you PRON nsubj
# 'd AUX aux
# have VERB ccomp
# to PART aux
# venture VERB xcomp
# further ADV advmod
# away ADV advmod
# to PART aux
# get VERB advcl
# good ADJ amod
# sushi NOUN dobj
# , PUNCT punct
# but CCONJ cc
# this DET det
# place NOUN nsubj
# really ADV advmod
# hit VERB conj
# the DET det
# spot NOUN dobj
# that DET det
# night NOUN npadvmod
# . PUNCT punct
# Host NOUN compound
# staff NOUN nsubj
# were AUX ROOT
# , PUNCT punct
# for ADP prep
# lack NOUN pobj
# of ADP prep
# a DET det
# better ADJ amod
# word NOUN pobj
# , PUNCT punct
# BITCHES PROPN appos
# ! PUNCT punct
# Bland PROPN ROOT
# ... PUNCT punct
# Not PART neg
# a DET det
# liking VERB ROOT
# this DET det
# place NOUN dobj
# for ADP prep
# a DET det
# number NOUN pobj
# of ADP prep
# reasons NOUN pobj
# and CCONJ cc
# I PRON nsubj
# do AUX aux
# n't PART neg
# want VERB conj
# to PART aux
# waste VERB xcomp
# time NOUN dobj
# on ADP prep
# bad ADJ amod
# reviewing NOUN pobj
# .. PUNCT punct
# I PRON nsubj
# 'll AUX aux
# leave VERB ROOT
# it PRON dobj
# at ADP prep
# that PRON pobj
# ... PUNCT punct
# Phenomenal ADJ amod
# food NOUN ROOT
# , PUNCT punct
# service NOUN conj
# and CCONJ cc
# ambiance NOUN conj
# . PUNCT punct
# I PRON nsubj
# would AUX aux
# n't PART neg
# return VERB ROOT
# . PUNCT punct
# Definitely ADV advmod
# worth ADJ advcl
# venturing VERB xcomp
# off ADP prep
# the DET det
# strip NOUN pobj
# for ADP prep
# the DET det
# pork NOUN compound
# belly NOUN pobj
# , PUNCT punct
# will AUX aux
# return VERB ROOT
# next ADJ amod
# time NOUN npadvmod
# I PRON nsubj
# 'm AUX relcl
# in ADP prep
# Vegas PROPN pobj
# . PUNCT punct
# This DET det
# place NOUN nsubj
# is AUX ROOT
# way ADV advmod
# too ADV advmod
# overpriced ADJ acomp
# for ADP prep
# mediocre ADJ amod
# food NOUN pobj
# . PUNCT punct
# Penne PROPN compound
# vodka NOUN nsubj
# excellent ADJ ROOT
# ! PUNCT punct
# They PRON nsubj
# have VERB ROOT
# a DET det
# good ADJ amod
# selection NOUN dobj
# of ADP prep
# food NOUN pobj
# including VERB prep
# a DET det
# massive ADJ amod
# meatloaf NOUN compound
# sandwich NOUN pobj
# , PUNCT punct
# a DET det
# crispy NOUN compound
# chicken PROPN compound
# wrap PROPN appos
# , PUNCT punct
# a DET det
# delish ADJ amod
# tuna NOUN compound
# melt NOUN conj
# and CCONJ cc
# some DET det
# tasty ADJ amod
# burgers NOUN conj
# . PUNCT punct
# The DET det
# management NOUN nsubj
# is AUX ROOT
# rude ADJ acomp
# . PUNCT punct
# Delicious PROPN compound
# NYC PROPN compound
# bagels NOUN ROOT
# , PUNCT punct
# good ADJ amod
# selections NOUN appos
# of ADP prep
# cream NOUN compound
# cheese NOUN pobj
# , PUNCT punct
# real ADJ amod
# Lox PROPN appos
# with ADP prep
# capers NOUN pobj
# even ADV advmod
# . PUNCT punct
# Great PROPN compound
# Subway PROPN nsubj
# , PUNCT punct
# in ADP prep
# fact NOUN pobj
# it PRON nsubj
# 's AUX ROOT
# so ADV advmod
# good ADJ acomp
# when SCONJ advmod
# you PRON nsubj
# come VERB advcl
# here ADV advmod
# every DET det
# other ADJ amod
# Subway PROPN nsubj
# will AUX aux
# not PART neg
# meet VERB ccomp
# your PRON poss
# expectations NOUN dobj
# . PUNCT punct
# I PRON nsubj
# had VERB ROOT
# a DET det
# seriously ADV advmod
# solid ADJ amod
# breakfast NOUN dobj
# here ADV advmod
# . PUNCT punct
# This PRON nsubj
# is AUX ROOT
# one NUM attr
# of ADP prep
# the DET det
# best ADJ amod
# bars NOUN pobj
# with ADP prep
# food NOUN pobj
# in ADP prep
# Vegas PROPN pobj
# . PUNCT punct
# He PRON nsubj
# was AUX ROOT
# extremely ADV advmod
# rude ADJ acomp
# and CCONJ cc
# really ADV advmod
# , PUNCT punct
# there PRON expl
# are VERB conj
# so ADV advmod
# many ADJ amod
# other ADJ amod
# restaurants NOUN attr
# I PRON nsubj
# would AUX aux
# love VERB relcl
# to PART aux
# dine VERB xcomp
# at ADP prep
# during ADP prep
# a DET det
# weekend NOUN pobj
# in ADP prep
# Vegas PROPN pobj
# . PUNCT punct
# My PRON poss
# drink NOUN nsubj
# was AUX ROOT
# never ADV neg
# empty ADJ acomp
# and CCONJ cc
# he PRON nsubj
# made VERB conj
# some DET det
# really ADV advmod
# great ADJ amod
# menu NOUN compound
# suggestions NOUN dobj
# . PUNCT punct
# Do AUX aux
# n't PART neg
# do VERB ROOT
# it PRON dobj
# ! PUNCT punct
# ! PUNCT punct
# ! PUNCT punct
# ! PUNCT punct
# The DET det
# waiter NOUN nsubj
# was AUX ROOT
# n't PART neg
# helpful ADJ acomp
# or CCONJ cc
# friendly ADJ conj
# and CCONJ cc
# rarely ADV advmod
# checked VERB conj
# on ADP prep
# us PRON pobj
# . PUNCT punct
# My PRON poss
# husband NOUN nsubj
# and CCONJ cc
# I PRON conj
# ate VERB ROOT
# lunch NOUN dobj
# here ADV advmod
# and CCONJ cc
# were AUX conj
# very ADV advmod
# disappointed ADJ acomp
# with ADP prep
# the DET det
# food NOUN pobj
# and CCONJ cc
# service NOUN conj
# . PUNCT punct
# And CCONJ cc
# the DET det
# red PROPN compound
# curry PROPN nsubj
# had VERB ROOT
# so ADV advmod
# much ADJ amod
# bamboo NOUN compound
# shoots NOUN dobj
# and CCONJ cc
# was AUX conj
# n't PART neg
# very ADV advmod
# tasty ADJ acomp
# to ADP prep
# me PRON pobj
# . PUNCT punct
# Nice ADJ amod
# blanket NOUN ROOT
# of ADP prep
# moz NOUN pobj
# over ADP prep
# top NOUN pobj
# but CCONJ cc
# i PRON nsubj
# feel VERB conj
# like SCONJ mark
# this PRON nsubjpass
# was AUX auxpass
# done VERB advcl
# to PART aux
# cover VERB advcl
# up ADP prt
# the DET det
# subpar ADJ amod
# food NOUN dobj
# . PUNCT punct
# The DET det
# bathrooms NOUN nsubj
# are AUX ROOT
# clean ADJ acomp
# and CCONJ cc
# the DET det
# place NOUN nsubjpass
# itself PRON appos
# is AUX auxpass
# well ADV advmod
# decorated VERB conj
# . PUNCT punct
# The DET det
# menu NOUN nsubj
# is AUX aux
# always ADV advmod
# changing VERB ccomp
# , PUNCT punct
# food NOUN compound
# quality NOUN nsubj
# is AUX aux
# going VERB ROOT
# down ADP advmod
# & CCONJ cc
# service NOUN nsubj
# is AUX conj
# extremely ADV advmod
# slow ADJ acomp
# . PUNCT punct
# The DET det
# service NOUN nsubj
# was AUX ROOT
# a DET det
# little ADJ amod
# slow ADJ attr
# , PUNCT punct
# considering VERB advcl
# that PRON nsubjpass
# were AUX auxpass
# served VERB ccomp
# by ADP agent
# 3 NUM nummod
# people NOUN compound
# servers NOUN pobj
# so SCONJ mark
# the DET det
# food NOUN nsubj
# was AUX aux
# coming VERB advcl
# in ADP prep
# a DET det
# slow ADJ amod
# pace NOUN pobj
# . PUNCT punct
# I PRON nsubj
# give VERB ccomp
# it PRON dative
# 2 NUM nummod
# thumbs NOUN dobj
# down ADV advmod
# We PRON nsubj
# watched VERB ROOT
# our PRON poss
# waiter NOUN nsubj
# pay VERB ccomp
# a DET det
# lot NOUN npadvmod
# more ADJ amod
# attention NOUN dobj
# to ADP prep
# other ADJ amod
# tables NOUN pobj
# and CCONJ cc
# ignore VERB conj
# us PRON dobj
# . PUNCT punct
# My PRON poss
# fiancé NOUN npadvmod
# and CCONJ cc
# I PRON nsubj
# came VERB ROOT
# in ADP prep
# the DET det
# middle NOUN pobj
# of ADP prep
# the DET det
# day NOUN pobj
# and CCONJ cc
# we PRON nsubjpass
# were AUX auxpass
# greeted VERB conj
# and CCONJ cc
# seated VERB conj
# right ADV advmod
# away ADV advmod
# . PUNCT punct
# This PRON nsubj
# is AUX ROOT
# a DET det
# great ADJ amod
# restaurant NOUN attr
# at ADP prep
# the DET det
# Mandalay PROPN compound
# Bay PROPN pobj
# . PUNCT punct
# We PRON nsubj
# waited VERB ROOT
# for ADP prep
# forty NUM compound
# five NUM nummod
# minutes NOUN pobj
# in ADP prep
# vain ADJ pobj
# . PUNCT punct
# Crostini PROPN nsubj
# that PRON nsubj
# came VERB relcl
# with ADP prep
# the DET det
# salad NOUN pobj
# was AUX ROOT
# stale ADJ acomp
# . PUNCT punct
# Some DET det
# highlights NOUN ROOT
# : PUNCT punct
# Great ADJ amod
# quality NOUN compound
# nigiri ADV advmod
# here ADV advmod
# ! PUNCT punct
# the DET det
# staff NOUN nsubj
# is AUX ROOT
# friendly ADJ acomp
# and CCONJ cc
# the DET det
# joint NOUN nsubj
# is AUX conj
# always ADV advmod
# clean ADJ acomp
# . PUNCT punct
# this PRON nsubj
# was AUX ROOT
# a DET det
# different ADJ amod
# cut NOUN attr
# than ADP prep
# the DET det
# piece NOUN pobj
# the DET det
# other ADJ amod
# day NOUN npadvmod
# but CCONJ cc
# still ADV advmod
# wonderful ADJ conj
# and CCONJ cc
# tender NOUN conj
# s NOUN dep
# well ADV advmod
# as ADV advmod
# well ADV advmod
# flavored VERB advcl
# . PUNCT punct
# I PRON nsubj
# ordered VERB ROOT
# the DET det
# Voodoo PROPN compound
# pasta NOUN dobj
# and CCONJ cc
# it PRON nsubj
# was AUX conj
# the DET det
# first ADJ amod
# time NOUN attr
# I PRON nsubj
# 'd AUX aux
# had VERB relcl
# really ADV advmod
# excellent ADJ amod
# pasta NOUN dobj
# since SCONJ prep
# going AUX auxpass
# gluten VERB pcomp
# free ADJ acomp
# several ADJ amod
# years NOUN npadvmod
# ago ADV advmod
# . PUNCT punct
# this DET det
# place NOUN nsubj
# is AUX ROOT
# good ADJ acomp
# . PUNCT punct
# Unfortunately ADV advmod
# , PUNCT punct
# we PRON nsubj
# must AUX aux
# have AUX aux
# hit VERB ROOT
# the DET det
# bakery NOUN dobj
# on ADP prep
# leftover NOUN compound
# day NOUN pobj
# because SCONJ mark
# everything PRON nsubj
# we PRON nsubj
# ordered VERB relcl
# was AUX advcl
# STALE PROPN attr
# . PUNCT punct
# I PRON nsubj
# came VERB ROOT
# back ADV advmod
# today NOUN npadvmod
# since SCONJ mark
# they PRON nsubj
# relocated VERB advcl
# and CCONJ cc
# still ADV advmod
# not PART neg
# impressed ADJ conj
# . PUNCT punct
# I PRON nsubjpass
# was AUX auxpass
# seated VERB ROOT
# immediately ADV advmod
# . PUNCT punct
# Their PRON poss
# menu NOUN nsubj
# is AUX ROOT
# diverse ADJ acomp
# , PUNCT punct
# and CCONJ cc
# reasonably ADV advmod
# priced VERB conj
# . PUNCT punct
# Avoid VERB ROOT
# at ADP prep
# all DET det
# cost NOUN pobj
# ! PUNCT punct
# Restaurant NOUN nsubj
# is AUX ROOT
# always ADV advmod
# full ADJ acomp
# but CCONJ cc
# never ADV neg
# a DET det
# wait NOUN conj
# . PUNCT punct
# DELICIOUS PROPN ROOT
# ! PUNCT punct
# ! PUNCT punct
# This DET det
# place NOUN nsubj
# is AUX ROOT
# hands NOUN attr
# - PUNCT punct
# down ADP prt
# one NUM appos
# of ADP prep
# the DET det
# best ADJ amod
# places NOUN pobj
# to PART aux
# eat VERB relcl
# in ADP prep
# the DET det
# Phoenix PROPN compound
# metro PROPN compound
# area NOUN pobj
# . PUNCT punct
# So ADV advmod
# do AUX aux
# n't PART neg
# go VERB ROOT
# there ADV advmod
# if SCONJ mark
# you PRON nsubj
# are AUX aux
# looking VERB advcl
# for ADP prep
# good ADJ amod
# food NOUN pobj
# ... PUNCT punct
# I PRON nsubjpass
# 've AUX aux
# never ADV neg
# been AUX auxpass
# treated VERB ROOT
# so ADV advmod
# bad ADJ oprd
# . PUNCT punct
# Bacon PROPN nsubj
# is AUX ROOT
# hella PROPN compound
# salty ADJ acomp
# . PUNCT punct
# We PRON nsubj
# also ADV advmod
# ordered VERB ccomp
# the DET det
# spinach NOUN dobj
# and CCONJ cc
# avocado VERB conj
# salad NOUN dobj
# ; PUNCT punct
# the DET det
# ingredients NOUN nsubj
# were AUX ROOT
# sad ADJ acomp
# and CCONJ cc
# the DET det
# dressing NOUN nsubj
# literally ADV advmod
# had VERB conj
# zero NUM nummod
# taste NOUN dobj
# . PUNCT punct
# This PRON nsubj
# really ADV advmod
# is AUX ROOT
# how SCONJ advmod
# Vegas PROPN nmod
# fine ADJ amod
# dining NOUN nsubj
# used VERB ccomp
# to PART aux
# be AUX xcomp
# , PUNCT punct
# right ADV advmod
# down ADV prep
# to ADP prep
# the DET det
# menus NOUN pobj
# handed VERB acl
# to ADP prep
# the DET det
# ladies NOUN pobj
# that PRON nsubj
# have VERB relcl
# no DET det
# prices NOUN dobj
# listed VERB acl
# . PUNCT punct
# The DET det
# waitresses NOUN nsubj
# are AUX ROOT
# very ADV advmod
# friendly ADJ acomp
# . PUNCT punct
# Lordy PROPN advcl
# , PUNCT punct
# the DET det
# Khao PROPN compound
# Soi PROPN nsubj
# is AUX ROOT
# a DET det
# dish NOUN attr
# that PRON nsubj
# is AUX relcl
# not PART neg
# to PART aux
# be AUX auxpass
# missed VERB xcomp
# for ADP prep
# curry NOUN compound
# lovers NOUN pobj
# ! PUNCT punct
# Everything PRON nsubj
# on ADP prep
# the DET det
# menu NOUN pobj
# is AUX ROOT
# terrific ADJ acomp
# and CCONJ cc
# we PRON nsubj
# were AUX conj
# also ADV advmod
# thrilled ADJ acomp
# that SCONJ mark
# they PRON nsubj
# made VERB ccomp
# amazing ADJ amod
# accommodations NOUN dobj
# for ADP prep
# our PRON poss
# vegetarian ADJ amod
# daughter NOUN pobj
# . PUNCT punct
# Perhaps ADV advmod
# I PRON nsubj
# caught VERB ROOT
# them PRON dobj
# on ADP prep
# an DET det
# off ADJ amod
# night NOUN pobj
# judging VERB advcl
# by ADP agent
# the DET det
# other ADJ amod
# reviews NOUN pobj
# , PUNCT punct
# but CCONJ cc
# I PRON nsubjpass
# 'm AUX auxpass
# not PART neg
# inspired VERB conj
# to PART aux
# go VERB xcomp
# back ADV advmod
# . PUNCT punct
# The DET det
# service NOUN nsubj
# here ADV advmod
# leaves VERB ROOT
# a DET det
# lot NOUN dobj
# to PART aux
# be AUX auxpass
# desired VERB relcl
# . PUNCT punct
# The DET det
# atmosphere NOUN nsubj
# is AUX ROOT
# modern ADJ acomp
# and CCONJ cc
# hip NOUN conj
# , PUNCT punct
# while SCONJ mark
# maintaining VERB advcl
# a DET det
# touch NOUN dobj
# of ADP prep
# coziness NOUN pobj
# . PUNCT punct
# Not PART neg
# a DET det
# weekly ADJ amod
# haunt NOUN ROOT
# , PUNCT punct
# but CCONJ cc
# definitely ADV advmod
# a DET det
# place NOUN conj
# to PART aux
# come VERB relcl
# back ADV advmod
# to ADP prep
# every PRON pobj
# once ADV advmod
# in ADP prep
# a DET det
# while NOUN pobj
# . PUNCT punct
# We PRON nsubj
# literally ADV advmod
# sat VERB ROOT
# there ADV advmod
# for ADP prep
# 20 NUM nummod
# minutes NOUN pobj
# with ADP prep
# no DET det
# one NOUN pobj
# asking VERB acl
# to PART aux
# take VERB xcomp
# our PRON poss
# order NOUN dobj
# . PUNCT punct
# The DET det
# burger NOUN nsubj
# had VERB ccomp
# absolutely ADV advmod
# no DET det
# flavor NOUN dobj
# - PUNCT punct
# the DET det
# meat NOUN nsubj
# itself PRON appos
# was AUX ccomp
# totally ADV advmod
# bland ADJ acomp
# , PUNCT punct
# the DET det
# burger NOUN nsubj
# was AUX ROOT
# overcooked ADJ acomp
# and CCONJ cc
# there PRON expl
# was VERB conj
# no DET det
# charcoal NOUN compound
# flavor NOUN attr
# . PUNCT punct
# I PRON nsubj
# also ADV advmod
# decided VERB ROOT
# not PART neg
# to PART aux
# send VERB xcomp
# it PRON dobj
# back ADV prt
# because SCONJ mark
# our PRON poss
# waitress NOUN nsubj
# looked VERB advcl
# like SCONJ mark
# she PRON nsubj
# was AUX advcl
# on ADP prep
# the DET det
# verge NOUN pobj
# of ADP prep
# having VERB pcomp
# a DET det
# heart NOUN compound
# attack NOUN dobj
# . PUNCT punct
# I PRON nsubj
# dressed VERB ROOT
# up ADP prt
# to PART aux
# be AUX auxpass
# treated VERB xcomp
# so ADV advmod
# rudely ADV advmod
# ! PUNCT punct
# It PRON nsubj
# was AUX ROOT
# probably ADV advmod
# dirt NOUN attr
# . PUNCT punct
# Love VERB ROOT
# this DET det
# place NOUN dobj
# , PUNCT punct
# hits VERB conj
# the DET det
# spot NOUN dobj
# when SCONJ advmod
# I PRON nsubj
# want VERB advcl
# something PRON dobj
# healthy ADJ amod
# but CCONJ cc
# not PART neg
# lacking VERB conj
# in ADP prep
# quantity NOUN pobj
# or CCONJ cc
# flavor NOUN conj
# . PUNCT punct
# I PRON nsubj
# ordered VERB ROOT
# the DET det
# Lemon PROPN compound
# raspberry NOUN compound
# ice NOUN compound
# cocktail NOUN dobj
# which PRON nsubj
# was AUX relcl
# also ADV advmod
# incredible ADJ acomp
# . PUNCT punct
# The DET det
# food NOUN nsubj
# sucked VERB ROOT
# , PUNCT punct
# which PRON dobj
# we PRON nsubj
# expected VERB advcl
# but CCONJ cc
# it PRON nsubj
# sucked VERB conj
# more ADJ dobj
# than SCONJ mark
# we PRON nsubj
# could AUX aux
# have AUX aux
# imagined VERB advcl
# . PUNCT punct
# Interesting ADJ amod
# decor NOUN ROOT
# . PUNCT punct
# What PRON dobj
# I PRON nsubj
# really ADV advmod
# like VERB intj
# there PRON expl
# is VERB ROOT
# the DET det
# crepe NOUN compound
# station NOUN attr
# . PUNCT punct
# Also ADV advmod
# were AUX auxpass
# served VERB ROOT
# hot ADJ amod
# bread NOUN dobj
# and CCONJ cc
# butter NOUN conj
# , PUNCT punct
# and CCONJ cc
# home NOUN nsubj
# made VERB conj
# potato NOUN compound
# chips NOUN dobj
# with ADP prep
# bacon NOUN compound
# bits NOUN pobj
# on ADP prep
# top ADJ pobj
# .... PUNCT punct
# very ADV advmod
# original ADJ amod
# and CCONJ cc
# very ADV advmod
# good ADJ conj
# . PUNCT punct
# you PRON nsubj
# can AUX aux
# watch VERB ROOT
# them PRON nsubj
# preparing VERB ccomp
# the DET det
# delicious ADJ amod
# food NOUN dobj
# ! PUNCT punct
# ) PUNCT punct
# Both PRON nsubj
# of ADP prep
# the DET det
# egg NOUN compound
# rolls NOUN pobj
# were AUX ROOT
# fantastic ADJ acomp
# . PUNCT punct
# When SCONJ advmod
# my PRON poss
# order NOUN nsubj
# arrived VERB advcl
# , PUNCT punct
# one NUM nsubj
# of ADP prep
# the DET det
# gyros NOUN pobj
# was AUX aux
# missing VERB ROOT
# . PUNCT punct
# I PRON nsubj
# had VERB ROOT
# a DET det
# salad NOUN dobj
# with ADP prep
# the DET det
# wings NOUN pobj
# , PUNCT punct
# and CCONJ cc
# some DET det
# ice NOUN compound
# cream NOUN conj
# for ADP prep
# dessert NOUN pobj
# and CCONJ cc
# left VERB conj
# feeling VERB xcomp
# quite ADV advmod
# satisfied ADJ acomp
# . PUNCT punct
# I PRON nsubj
# 'm AUX ROOT
# not PART neg
# really ADV advmod
# sure ADJ acomp
# how SCONJ advmod
# Joey PROPN nsubjpass
# 's PART case
# was AUX auxpass
# voted VERB ccomp
# best ADJ amod
# hot ADJ amod
# dog NOUN oprd
# in ADP prep
# the DET det
# Valley PROPN pobj
# by ADP agent
# readers NOUN pobj
# of ADP prep
# Phoenix PROPN compound
# Magazine PROPN pobj
# . PUNCT punct
# The DET det
# best ADJ amod
# place NOUN ROOT
# to PART aux
# go VERB relcl
# for ADP prep
# a DET det
# tasty ADJ amod
# bowl NOUN pobj
# of ADP prep
# Pho PROPN pobj
# ! PUNCT punct
# The DET det
# live ADJ amod
# music NOUN nsubj
# on ADP prep
# Fridays PROPN pobj
# totally ADV advmod
# blows VERB ROOT
# . PUNCT punct
# I PRON nsubj
# 've AUX aux
# never ADV neg
# been AUX ROOT
# more ADV advmod
# insulted VERB acomp
# or CCONJ cc
# felt VERB conj
# disrespected VERB acomp
# . PUNCT punct
# Very ADV advmod
# friendly ADJ amod
# staff NOUN ROOT
# . PUNCT punct
# It PRON nsubj
# is AUX ROOT
# worth ADJ acomp
# the DET det
# drive NOUN npadvmod
# . PUNCT punct
# I PRON nsubj
# had AUX aux
# heard VERB ROOT
# good ADJ amod
# things NOUN dobj
# about ADP prep
# this DET det
# place NOUN pobj
# , PUNCT punct
# but CCONJ cc
# it PRON nsubj
# exceeding VERB conj
# every DET det
# hope NOUN dobj
# I PRON nsubj
# could AUX aux
# have AUX aux
# dreamed VERB relcl
# of ADP prep
# . PUNCT punct
# Food NOUN nsubj
# was AUX ROOT
# great ADJ acomp
# and CCONJ cc
# so ADV advmod
# was AUX conj
# the DET det
# serivce NOUN nsubj
# ! PUNCT punct
# The DET det
# warm ADJ amod
# beer NOUN nsubj
# did AUX aux
# n't PART neg
# help VERB ROOT
# . PUNCT punct
# Great ADJ amod
# brunch NOUN compound
# spot NOUN ROOT
# . PUNCT punct
# Service NOUN nsubj
# is AUX ROOT
# friendly ADJ acomp
# and CCONJ cc
# inviting VERB conj
# . PUNCT punct
# Very ADV advmod
# good ADJ amod
# lunch NOUN compound
# spot NOUN ROOT
# . PUNCT punct
# I PRON nsubj
# 've AUX aux
# lived VERB ROOT
# here ADV advmod
# since SCONJ prep
# 1979 NUM pobj
# and CCONJ cc
# this PRON nsubj
# was AUX conj
# the DET det
# first ADJ amod
# ( PUNCT punct
# and CCONJ cc
# last ADJ conj
# ) PUNCT punct
# time NOUN attr
# I PRON nsubj
# 've AUX aux
# stepped VERB relcl
# foot NOUN dobj
# into ADP prep
# this DET det
# place NOUN pobj
# . PUNCT punct
# The DET det
# WORST ADJ amod
# EXPERIENCE NOUN ROOT
# EVER ADV advmod
# . PUNCT punct
# Must AUX aux
# have AUX aux
# been AUX ROOT
# an DET det
# off ADJ amod
# night NOUN attr
# at ADP prep
# this DET det
# place NOUN pobj
# . PUNCT punct
# The DET det
# sides NOUN nsubj
# are AUX ROOT
# delish ADJ advmod
# - PUNCT punct
# mixed VERB amod
# mushrooms NOUN attr
# , PUNCT punct
# yukon PROPN compound
# gold PROPN compound
# puree ADJ appos
# , PUNCT punct
# white ADJ amod
# corn NOUN npadvmod
# - PUNCT punct
# beateous ADJ acomp
# . PUNCT punct
# If SCONJ mark
# that DET det
# bug NOUN nsubj
# never ADV neg
# showed VERB advcl
# up ADP prt
# I PRON nsubj
# would AUX aux
# have AUX aux
# given VERB ROOT
# a DET det
# 4 NUM dobj
# for ADP prep
# sure ADJ amod
# , PUNCT punct
# but CCONJ cc
# on ADP prep
# the DET det
# other ADJ amod
# side NOUN pobj
# of ADP prep
# the DET det
# wall NOUN pobj
# where SCONJ advmod
# this DET det
# bug NOUN nsubj
# was AUX aux
# climbing VERB relcl
# was AUX conj
# the DET det
# kitchen NOUN attr
# . PUNCT punct
# For ADP prep
# about ADV advmod
# 10 NUM nummod
# minutes NOUN pobj
# , PUNCT punct
# we PRON nsubj
# we PRON nsubj
# 're AUX aux
# waiting VERB ROOT
# for ADP prep
# her PRON poss
# salad NOUN pobj
# when SCONJ advmod
# we PRON nsubj
# realized VERB advcl
# that SCONJ mark
# it PRON nsubj
# was AUX aux
# n't PART neg
# coming VERB ccomp
# any DET det
# time NOUN npadvmod
# soon ADV advmod
# . PUNCT punct
# My PRON poss
# friend NOUN nsubj
# loved VERB ROOT
# the DET det
# salmon NOUN compound
# tartar NOUN dobj
# . PUNCT punct
# Wo AUX aux
# n't PART neg
# go VERB ROOT
# back ADV advmod
# . PUNCT punct
# Extremely ADV advmod
# Tasty PROPN ROOT
# ! PUNCT punct
# Waitress PROPN nsubj
# was AUX ROOT
# good ADJ acomp
# though ADV advmod
# ! PUNCT punct
# Soggy PROPN ROOT
# and CCONJ cc
# not PART neg
# good ADJ conj
# . PUNCT punct
# The DET det
# Jamaican ADJ amod
# mojitos NOUN nsubj
# are AUX ROOT
# delicious ADJ acomp
# . PUNCT punct
# Which PRON nsubj
# are AUX ROOT
# small ADJ acomp
# and CCONJ cc
# not PART neg
# worth ADJ conj
# the DET det
# price NOUN npadvmod
# . PUNCT punct
# - PUNCT punct
# the DET det
# food NOUN nsubj
# is AUX ROOT
# rich ADJ acomp
# so SCONJ prep
# order NOUN dep
# accordingly ADV advmod
# . PUNCT punct
# The DET det
# shower NOUN compound
# area NOUN nsubj
# is AUX ROOT
# outside ADV advmod
# so SCONJ mark
# you PRON nsubj
# can AUX aux
# only ADV advmod
# rinse VERB advcl
# , PUNCT punct
# not PART neg
# take VERB dep
# a DET det
# full ADJ amod
# shower NOUN dobj
# , PUNCT punct
# unless SCONJ mark
# you PRON nsubj
# do AUX aux
# n't PART neg
# mind VERB advcl
# being AUX xcomp
# nude ADJ acomp
# for SCONJ mark
# everyone PRON nsubj
# to PART aux
# see VERB advcl
# ! PUNCT punct
# The DET det
# service NOUN nsubj
# was AUX ROOT
# a DET det
# bit NOUN npadvmod
# lacking ADJ acomp
# . PUNCT punct
# Lobster PROPN compound
# Bisque PROPN nsubj
# , PUNCT punct
# Bussell PROPN compound
# Sprouts PROPN conj
# , PUNCT punct
# Risotto PROPN conj
# , PUNCT punct
# Filet PROPN conj
# ALL PRON appos
# needed VERB ROOT
# salt NOUN dobj
# and CCONJ cc
# pepper NOUN conj
# .. PUNCT punct
# and CCONJ cc
# of ADP prep
# course NOUN pobj
# there PRON expl
# is VERB conj
# none NOUN attr
# at ADP prep
# the DET det
# tables NOUN pobj
# . PUNCT punct
# Hopefully ADV advmod
# this PRON nsubj
# bodes VERB ROOT
# for ADP prep
# them PRON pobj
# going VERB advcl
# out ADP prep
# of ADP prep
# business NOUN pobj
# and CCONJ cc
# someone PRON nsubj
# who PRON nsubj
# can AUX aux
# cook VERB relcl
# can AUX aux
# come VERB conj
# in ADP prt
# . PUNCT punct
# It PRON nsubj
# was AUX ROOT
# either CCONJ preconj
# too ADV advmod
# cold ADJ amod
# , PUNCT punct
# not PART neg
# enough ADJ amod
# flavor NOUN attr
# or CCONJ cc
# just ADV advmod
# bad ADJ conj
# . PUNCT punct
# I PRON nsubj
# loved VERB ROOT
# the DET det
# bacon NOUN nsubj
# wrapped VERB ccomp
# dates NOUN dobj
# . PUNCT punct
# This PRON nsubj
# is AUX ROOT
# an DET det
# unbelievable ADJ amod
# BARGAIN NOUN attr
# ! PUNCT punct
# The DET det
# folks NOUN nsubj
# at ADP prep
# Otto PROPN pobj
# always ADV advmod
# make VERB ROOT
# us PRON nsubj
# feel VERB ccomp
# so ADV advmod
# welcome ADJ acomp
# and CCONJ cc
# special ADJ conj
# . PUNCT punct
# As ADP prep
# for ADP prep
# the DET det
# " PUNCT punct
# mains NOUN pobj
# , PUNCT punct
# " PUNCT punct
# also ADV advmod
# uninspired ADJ ROOT
# . PUNCT punct
# This PRON nsubj
# is AUX ROOT
# the DET det
# place NOUN attr
# where SCONJ advmod
# I PRON nsubj
# first ADV advmod
# had VERB relcl
# pho NOUN dobj
# and CCONJ cc
# it PRON nsubj
# was AUX conj
# amazing ADJ acomp
# ! PUNCT punct
# ! PUNCT punct
# This DET det
# wonderful ADJ amod
# experience NOUN nsubj
# made VERB ROOT
# this DET det
# place NOUN nsubj
# a DET det
# must AUX aux
# - PUNCT punct
# stop VERB ccomp
# whenever SCONJ advmod
# we PRON nsubj
# are AUX advcl
# in ADP prep
# town NOUN pobj
# again ADV advmod
# . PUNCT punct
# If SCONJ mark
# the DET det
# food NOUN nsubj
# is AUX advcl
# n't PART neg
# bad ADJ acomp
# enough ADV advmod
# for ADP prep
# you PRON pobj
# , PUNCT punct
# then ADV advmod
# enjoy VERB ROOT
# dealing VERB xcomp
# with ADP prep
# the DET det
# world NOUN poss
# 's PART case
# worst ADJ amod
# / SYM punct
# annoying ADJ amod
# drunk ADJ amod
# people NOUN pobj
# . PUNCT punct
# Very ADV advmod
# very ADV advmod
# fun ADJ amod
# chef NOUN ROOT
# . PUNCT punct
# Ordered VERB ROOT
# a DET det
# double ADJ amod
# cheeseburger NOUN dobj
# & CCONJ cc
# got VERB conj
# a DET det
# single ADJ amod
# patty NOUN dobj
# that PRON nsubj
# was AUX aux
# falling VERB relcl
# apart ADV advmod
# ( PUNCT punct
# picture NOUN nsubj
# uploaded VERB ccomp
# ) PUNCT punct
# Yeah INTJ intj
# , PUNCT punct
# still ADV advmod
# sucks VERB ROOT
# . PUNCT punct
# Great ADJ amod
# place NOUN ROOT
# to PART aux
# have VERB relcl
# a DET quantmod
# couple NOUN nummod
# drinks NOUN dobj
# and CCONJ cc
# watch VERB conj
# any PRON dobj
# and CCONJ cc
# all DET det
# sporting NOUN compound
# events NOUN conj
# as SCONJ mark
# the DET det
# walls NOUN nsubjpass
# are AUX auxpass
# covered VERB advcl
# with ADP prep
# TV NOUN pobj
# 's PART case
# . PUNCT punct
# If SCONJ mark
# it PRON nsubj
# were AUX advcl
# possible ADJ acomp
# to PART aux
# give VERB xcomp
# them PRON dative
# zero NUM nummod
# stars NOUN dobj
# , PUNCT punct
# they PRON nsubj
# 'd AUX aux
# have VERB ROOT
# it PRON dobj
# . PUNCT punct
# The DET det
# descriptions NOUN nsubj
# said VERB ccomp
# " PUNCT punct
# yum INTJ compound
# yum PROPN compound
# sauce NOUN ccomp
# " PUNCT punct
# and CCONJ cc
# another PRON nsubj
# said VERB conj
# " PUNCT punct
# eel NOUN compound
# sauce NOUN dobj
# " PUNCT punct
# , PUNCT punct
# yet ADV advmod
# another PRON nsubj
# said VERB ROOT
# " PUNCT punct
# spicy ADJ compound
# mayo" PROPN dobj
# ... PUNCT punct
# well INTJ intj
# NONE NOUN nsubj
# of ADP prep
# the DET det
# rolls NOUN pobj
# had VERB ROOT
# sauces NOUN dobj
# on ADP prep
# them PRON pobj
# . PUNCT punct
# I PRON nsubj
# 'd AUX aux
# say VERB ROOT
# that PRON nsubj
# would AUX aux
# be AUX ccomp
# the DET det
# hardest ADJ amod
# decision NOUN attr
# ... PUNCT punct
# Honestly ADV advmod
# , PUNCT punct
# all PRON nsubj
# of ADP prep
# M PROPN poss
# 's PART case
# dishes NOUN pobj
# taste VERB ROOT
# how SCONJ advmod
# they PRON nsubjpass
# are AUX auxpass
# supposed VERB ccomp
# to PART aux
# taste VERB xcomp
# ( PUNCT punct
# amazing ADJ dobj
# ) PUNCT punct
# . PUNCT punct
# If SCONJ mark
# she PRON nsubj
# had AUX aux
# not PART neg
# rolled VERB ROOT
# the DET det
# eyes NOUN dobj
# we PRON nsubj
# may AUX aux
# have AUX aux
# stayed VERB relcl
# ... PUNCT punct
# Not PART neg
# sure ADJ ROOT
# if SCONJ mark
# we PRON nsubj
# will AUX aux
# go VERB ccomp
# back ADV advmod
# and CCONJ cc
# try VERB conj
# it PRON dobj
# again ADV advmod
# . PUNCT punct
# Everyone PRON nsubj
# is AUX ROOT
# very ADV advmod
# attentive ADJ acomp
# , PUNCT punct
# ...
# could AUX aux
# barely ADV advmod
# stomach VERB ROOT
# the DET det
# meal NOUN dobj
# , PUNCT punct
# but CCONJ cc
# did AUX aux
# n't PART neg
# complain VERB conj
# because SCONJ mark
# it PRON nsubj
# was AUX advcl
# a DET det
# business NOUN compound
# lunch NOUN attr
# . PUNCT punct
# It PRON nsubj
# was AUX ccomp
# so ADV advmod
# bad ADJ acomp
# , PUNCT punct
# I PRON nsubj
# had AUX aux
# lost VERB ROOT
# the DET det
# heart NOUN dobj
# to PART aux
# finish VERB advcl
# it PRON dobj
# . PUNCT punct
# It PRON nsubj
# also ADV advmod
# took VERB ROOT
# her PRON dobj
# forever ADV advmod
# to PART aux
# bring VERB advcl
# us PRON dative
# the DET det
# check NOUN dobj
# when SCONJ advmod
# we PRON nsubj
# asked VERB advcl
# for ADP prep
# it PRON pobj
# . PUNCT punct
# We PRON nsubj
# are AUX ROOT
# n't PART neg
# ones NOUN attr
# to PART aux
# make VERB advcl
# a DET det
# scene NOUN dobj
# at ADP prep
# restaurants NOUN pobj
# but CCONJ cc
# I PRON nsubj
# just ADV advmod
# do AUX aux
# n't PART neg
# get VERB conj
# it PRON dobj
# ... PUNCT punct
# definitely ADV advmod
# lost VERB ccomp
# the DET det
# love NOUN dobj
# after ADP prep
# this DET det
# one NOUN pobj
# ! PUNCT punct
# Disappointing ADJ amod
# experience NOUN ROOT
# . PUNCT punct
# The DET det
# food NOUN nsubj
# is AUX ROOT
# about ADP prep
# on ADP prep
# par NOUN pobj
# with ADP prep
# Denny PROPN pobj
# 's PART case
# , PUNCT punct
# which PRON nsubj
# is AUX relcl
# to PART aux
# say VERB xcomp
# , PUNCT punct
# not PART neg
# good ADJ acomp
# at ADV advmod
# all ADV advmod
# . PUNCT punct
# If SCONJ mark
# you PRON nsubj
# want VERB advcl
# to PART aux
# wait VERB xcomp
# for ADP prep
# mediocre ADJ amod
# food NOUN pobj
# and CCONJ cc
# downright ADJ amod
# terrible ADJ amod
# service NOUN conj
# , PUNCT punct
# then ADV advmod
# this PRON nsubj
# is AUX ROOT
# the DET det
# place NOUN attr
# for ADP prep
# you PRON pobj
# . PUNCT punct
# WAAAAAAyyyyyyyyyy PROPN nsubj
# over ADP advmod
# rated VERB acl
# is AUX ROOT
# all PRON attr
# I PRON nsubj
# am AUX aux
# saying VERB relcl
# . PUNCT punct
# We PRON nsubj
# wo AUX aux
# n't PART neg
# be AUX aux
# going VERB ROOT
# back ADV advmod
# . PUNCT punct
# The DET det
# place NOUN nsubj
# was AUX ROOT
# fairly ADV advmod
# clean ADJ acomp
# but CCONJ cc
# the DET det
# food NOUN nsubj
# simply ADV advmod
# was AUX conj
# n't PART neg
# worth ADJ acomp
# it PRON npadvmod
# . PUNCT punct
# This DET det
# place NOUN nsubj
# lacked VERB ROOT
# style NOUN dobj
# ! PUNCT punct
# ! PUNCT punct
# The DET det
# sangria NOUN nsubj
# was AUX ROOT
# about ADV advmod
# half NOUN attr
# of ADP prep
# a DET det
# glass NOUN compound
# wine NOUN pobj
# full ADJ amod
# and CCONJ cc
# was AUX conj
# $ SYM nmod
# 12 NUM attr
# , PUNCT punct
# ridiculous ADJ acomp
# . PUNCT punct
# Do AUX aux
# n't PART neg
# bother VERB ROOT
# coming VERB xcomp
# here ADV advmod
# . PUNCT punct
# The DET det
# meat NOUN nsubj
# was AUX ccomp
# pretty ADV advmod
# dry ADJ acomp
# , PUNCT punct
# I PRON nsubj
# had VERB ROOT
# the DET det
# sliced ADJ amod
# brisket NOUN dobj
# and CCONJ cc
# pulled VERB conj
# pork NOUN dobj
# . PUNCT punct
# The DET det
# building NOUN nsubj
# itself PRON appos
# seems VERB ccomp
# pretty ADV advmod
# neat ADJ oprd
# ; PUNCT punct
# the DET det
# bathroom NOUN nsubj
# is AUX ROOT
# pretty ADV advmod
# trippy ADJ acomp
# , PUNCT punct
# but CCONJ cc
# I PRON nsubj
# would AUX aux
# n't PART neg
# eat VERB conj
# here ADV advmod
# again ADV advmod
# . PUNCT punct
# It PRON nsubj
# was AUX ROOT
# equally ADV advmod
# awful ADJ acomp
# . PUNCT punct
# Probably ADV advmod
# not PART neg
# in ADP ROOT
# a DET det
# hurry NOUN pobj
# to PART aux
# go VERB acl
# back ADV advmod
# . PUNCT punct
# very ADV advmod
# slow ADV ROOT
# at ADP prep
# seating NOUN pobj
# even ADV advmod
# with ADP prep
# reservation NOUN pobj
# . PUNCT punct
# Not PART neg
# good ADJ ROOT
# by ADP prep
# any DET det
# stretch NOUN pobj
# of ADP prep
# the DET det
# imagination NOUN pobj
# . PUNCT punct
# The DET det
# cashew NOUN compound
# cream NOUN compound
# sauce NOUN nsubj
# was AUX ROOT
# bland ADJ acomp
# and CCONJ cc
# the DET det
# vegetables NOUN nsubj
# were AUX conj
# undercooked ADJ acomp
# . PUNCT punct
# The DET det
# chipolte ADJ compound
# ranch NOUN compound
# dipping NOUN compound
# sause NOUN nsubj
# was AUX ROOT
# tasteless ADJ acomp
# , PUNCT punct
# seemed VERB conj
# thin ADJ oprd
# and CCONJ cc
# watered VERB conj
# down ADP prt
# with ADP prep
# no DET det
# heat NOUN pobj
# . PUNCT punct
# It PRON nsubj
# was AUX ROOT
# a DET det
# bit NOUN npadvmod
# too ADV advmod
# sweet ADJ amod
# , PUNCT punct
# not PART neg
# really ADV advmod
# spicy ADJ acomp
# enough ADV advmod
# , PUNCT punct
# and CCONJ cc
# lacked VERB conj
# flavor NOUN dobj
# . PUNCT punct
# I PRON nsubj
# was AUX ROOT
# VERY ADV advmod
# disappointed ADJ acomp
# ! PUNCT punct
# ! PUNCT punct
# This DET det
# place NOUN nsubj
# is AUX ROOT
# horrible ADJ acomp
# and CCONJ cc
# way NOUN npadvmod
# overpriced ADJ conj
# . PUNCT punct
# Maybe ADV advmod
# it PRON nsubj
# 's AUX ROOT
# just ADV advmod
# their PRON poss
# Vegetarian ADJ amod
# fare NOUN attr
# , PUNCT punct
# but CCONJ cc
# I PRON nsubj
# 've AUX aux
# been AUX conj
# twice ADV advmod
# and CCONJ cc
# I PRON nsubj
# thought VERB conj
# it PRON nsubj
# was AUX ccomp
# average ADJ acomp
# at ADV advmod
# best ADV advmod
# . PUNCT punct
# It PRON nsubj
# was AUX ROOT
# n't PART neg
# busy ADJ acomp
# at ADV advmod
# all ADV advmod
# and CCONJ cc
# now ADV advmod
# we PRON nsubj
# know VERB conj
# why SCONJ advmod
# . PUNCT punct
# The DET det
# tables NOUN nsubj
# outside ADV advmod
# are AUX ROOT
# also ADV advmod
# dirty ADJ acomp
# a DET det
# lot NOUN attr
# of ADP prep
# the DET det
# time NOUN pobj
# and CCONJ cc
# the DET det
# workers NOUN nsubj
# are AUX conj
# not PART neg
# always ADV advmod
# friendly ADJ acomp
# and CCONJ cc
# helpful ADJ conj
# with ADP prep
# the DET det
# menu NOUN pobj
# . PUNCT punct
# The DET det
# ambiance NOUN nsubj
# here ADV advmod
# did AUX aux
# not PART neg
# feel VERB ROOT
# like ADP prep
# a DET det
# buffet NOUN compound
# setting NOUN pobj
# , PUNCT punct
# but CCONJ cc
# more ADJ conj
# of ADP prep
# a DET det
# douchey NOUN nmod
# indoor ADJ amod
# garden NOUN pobj
# for ADP prep
# tea NOUN pobj
# and CCONJ cc
# biscuits NOUN conj
# . PUNCT punct
# Con NOUN ROOT
# : PUNCT punct
# spotty ADJ amod
# service NOUN appos
# . PUNCT punct
# The DET det
# fries NOUN nsubj
# were AUX ROOT
# not PART neg
# hot ADJ acomp
# , PUNCT punct
# and CCONJ cc
# neither PRON preconj
# was AUX conj
# my PRON poss
# burger NOUN attr
# . PUNCT punct
# But CCONJ cc
# then ADV advmod
# they PRON nsubj
# came VERB ROOT
# back ADV advmod
# cold ADJ acomp
# . PUNCT punct
# Then ADV advmod
# our PRON poss
# food NOUN nsubj
# came VERB ccomp
# out ADP prt
# , PUNCT punct
# disappointment NOUN nsubj
# ensued VERB ROOT
# . PUNCT punct
# The DET det
# real ADJ amod
# disappointment NOUN nsubj
# was AUX ROOT
# our PRON poss
# waiter NOUN attr
# . PUNCT punct
# My PRON poss
# husband NOUN nsubj
# said VERB ROOT
# she PRON nsubj
# was AUX ccomp
# very ADV advmod
# rude ADJ acomp
# ... PUNCT punct
# did AUX aux
# not PART neg
# even ADV advmod
# apologize VERB ccomp
# for ADP prep
# the DET det
# bad ADJ amod
# food NOUN pobj
# or CCONJ cc
# anything PRON conj
# . PUNCT punct
# The DET det
# only ADJ amod
# reason NOUN nsubj
# to PART aux
# eat VERB relcl
# here ADV advmod
# would AUX aux
# be AUX ROOT
# to PART aux
# fill VERB xcomp
# up ADP prt
# before ADP prep
# a DET det
# night NOUN pobj
# of ADP prep
# binge NOUN pobj
# drinking VERB advcl
# just ADV advmod
# to PART aux
# get VERB xcomp
# some DET det
# carbs NOUN dobj
# in ADP prep
# your PRON poss
# stomach NOUN pobj
# . PUNCT punct
# Insults NOUN ROOT
# , PUNCT punct
# profound ADJ amod
# deuchebaggery NOUN appos
# , PUNCT punct
# and CCONJ cc
# had VERB conj
# to PART aux
# go VERB xcomp
# outside ADV advmod
# for ADP prep
# a DET det
# smoke NOUN compound
# break NOUN pobj
# while SCONJ mark
# serving VERB advcl
# just ADV advmod
# to PART aux
# solidify VERB advcl
# it PRON dobj
# . PUNCT punct
# If SCONJ mark
# someone PRON nsubj
# orders VERB advcl
# two NUM nummod
# tacos NOUN dobj
# do AUX aux
# n't PART neg
# ' PUNCT punct
# you PRON nsubj
# think VERB ROOT
# it PRON nsubj
# may AUX aux
# be AUX ccomp
# part NOUN attr
# of ADP prep
# customer NOUN compound
# service NOUN pobj
# to PART aux
# ask VERB advcl
# if SCONJ mark
# it PRON nsubj
# is AUX ccomp
# combo ADJ amod
# or CCONJ cc
# ala NOUN conj
# cart NOUN attr
# ? PUNCT punct
# She PRON nsubj
# was AUX ROOT
# quite ADV advmod
# disappointed ADJ acomp
# although SCONJ mark
# some DET det
# blame NOUN nsubj
# needs VERB advcl
# to PART aux
# be AUX auxpass
# placed VERB xcomp
# at ADP prep
# her PRON poss
# door NOUN pobj
# . PUNCT punct
# After ADP prep
# all DET predet
# the DET det
# rave NOUN compound
# reviews NOUN pobj
# I PRON nsubj
# could AUX aux
# n't PART neg
# wait VERB ROOT
# to PART aux
# eat VERB xcomp
# here ADV advmod
# ...... PUNCT punct
# what DET det
# a DET det
# disappointment NOUN ROOT
# ! PUNCT punct
# Del PROPN compound
# Taco PROPN nsubj
# is AUX ROOT
# pretty ADV advmod
# nasty ADJ acomp
# and CCONJ cc
# should AUX aux
# be AUX auxpass
# avoided VERB conj
# if SCONJ mark
# possible ADJ advcl
# . PUNCT punct
# It PRON nsubj
# 's AUX ROOT
# NOT PART neg
# hard ADJ acomp
# to PART aux
# make VERB xcomp
# a DET det
# decent ADJ amod
# hamburger NOUN dobj
# . PUNCT punct
# But CCONJ cc
# I PRON nsubj
# do AUX aux
# n't PART neg
# like VERB ROOT
# it PRON dobj
# . PUNCT punct
# Hell INTJ intj
# no INTJ intj
# will AUX aux
# I PRON nsubj
# go VERB ROOT
# back ADV advmod
# We PRON nsubj
# 've AUX aux
# have AUX aux
# gotten VERB ccomp
# a DET det
# much ADV advmod
# better ADJ amod
# service NOUN dobj
# from ADP prep
# the DET det
# pizza NOUN compound
# place NOUN pobj
# next ADJ prep
# door NOUN pobj
# than ADP prep
# the DET det
# services NOUN pobj
# we PRON nsubj
# received VERB relcl
# from ADP prep
# this DET det
# restaurant NOUN pobj
# . PUNCT punct
# I PRON nsubj
# do AUX aux
# n't PART neg
# know VERB ROOT
# what PRON attr
# the DET det
# big ADJ amod
# deal NOUN nsubj
# is AUX ccomp
# about ADP prep
# this DET det
# place NOUN pobj
# , PUNCT punct
# but CCONJ cc
# I PRON nsubj
# wo AUX aux
# n't PART neg
# be AUX conj
# back ADV advmod
# " PUNCT punct
# ya'all PROPN attr
# " PUNCT punct
# . PUNCT punct
# I PRON nsubj
# immediately ADV advmod
# said VERB ROOT
# I PRON nsubj
# wanted VERB ccomp
# to PART aux
# talk VERB xcomp
# to ADP prep
# the DET det
# manager NOUN pobj
# but CCONJ cc
# I PRON nsubj
# did AUX aux
# not PART neg
# want VERB conj
# to PART aux
# talk VERB xcomp
# to ADP prep
# the DET det
# guy NOUN pobj
# who PRON nsubj
# was AUX aux
# doing VERB relcl
# shots NOUN dobj
# of ADP prep
# fireball NOUN pobj
# behind ADP prep
# the DET det
# bar NOUN pobj
# . PUNCT punct
# The DET det
# ambiance NOUN nsubj
# is AUX ROOT
# n't PART neg
# much ADV advmod
# better ADJ acomp
# . PUNCT punct
# Unfortunately ADV advmod
# , PUNCT punct
# it PRON nsubj
# only ADV advmod
# set VERB ROOT
# us PRON dobj
# up ADP prt
# for ADP prep
# disapppointment ADJ amod
# with ADP prep
# our PRON poss
# entrees NOUN pobj
# . PUNCT punct
# The DET det
# food NOUN nsubj
# was AUX ROOT
# n't PART neg
# good ADJ acomp
# . PUNCT punct
# Your PRON poss
# servers NOUN nsubj
# suck VERB ccomp
# , PUNCT punct
# wait VERB dep
# , PUNCT punct
# correction NOUN npadvmod
# , PUNCT punct
# our PRON poss
# server NOUN nsubj
# Heimer PROPN appos
# sucked VERB ROOT
# . PUNCT punct
# What PRON nsubj
# happened VERB csubj
# next ADV advmod
# was AUX ROOT
# pretty ADJ acomp
# .... PUNCT punct
# off ADP prep
# putting VERB pobj
# . PUNCT punct
# too ADV advmod
# bad ADJ amod
# cause SCONJ dobj
# I PRON nsubj
# know VERB advcl
# it PRON nsubj
# 's AUX auxpass
# family NOUN npadvmod
# owned VERB ccomp
# , PUNCT punct
# I PRON nsubj
# really ADV advmod
# wanted VERB ROOT
# to PART aux
# like VERB xcomp
# this DET det
# place NOUN dobj
# . PUNCT punct
# Overpriced VERB ROOT
# for ADP prep
# what PRON dobj
# you PRON nsubj
# are AUX aux
# getting VERB pcomp
# . PUNCT punct
# I PRON nsubj
# vomited VERB ROOT
# in ADP prep
# the DET det
# bathroom NOUN pobj
# mid PROPN compound
# lunch NOUN dobj
# . PUNCT punct
# I PRON nsubj
# kept VERB ROOT
# looking VERB xcomp
# at ADP prep
# the DET det
# time NOUN pobj
# and CCONJ cc
# it PRON nsubj
# had AUX aux
# soon ADV advmod
# become VERB conj
# 35 NUM nummod
# minutes NOUN attr
# , PUNCT punct
# yet CCONJ advmod
# still ADV advmod
# no DET det
# food NOUN conj
# . PUNCT punct
# I PRON nsubj
# have AUX aux
# been AUX ROOT
# to ADP prep
# very ADV advmod
# few ADJ amod
# places NOUN pobj
# to PART aux
# eat VERB xcomp
# that PRON mark
# under ADP prep
# no DET det
# circumstances NOUN pobj
# would AUX aux
# I PRON nsubj
# ever ADV advmod
# return VERB ccomp
# to ADP prep
# , PUNCT punct
# and CCONJ cc
# this PRON nsubj
# tops VERB conj
# the DET det
# list NOUN dobj
# . PUNCT punct
# We PRON nsubj
# started VERB ROOT
# with ADP prep
# the DET det
# tuna NOUN compound
# sashimi PROPN pobj
# which PRON nsubj
# was AUX relcl
# brownish ADJ acomp
# in ADP prep
# color NOUN pobj
# and CCONJ cc
# obviously ADV advmod
# was AUX conj
# n't PART neg
# fresh ADJ acomp
# . PUNCT punct
# Food NOUN nsubj
# was AUX ROOT
# below ADP prep
# average NOUN pobj
# . PUNCT punct
# It PRON nsubj
# sure ADV advmod
# does AUX aux
# beat VERB ROOT
# the DET det
# nachos NOUN dobj
# at ADP prep
# the DET det
# movies NOUN pobj
# but CCONJ cc
# I PRON nsubj
# would AUX aux
# expect VERB conj
# a DET det
# little ADJ amod
# bit NOUN npadvmod
# more ADV advmod
# coming VERB ccomp
# from ADP prep
# a DET det
# restaurant NOUN pobj
# . PUNCT punct
# All ADV advmod
# in ADV advmod
# all PRON advmod
# , PUNCT punct
# Ha PROPN compound
# Long PROPN compound
# Bay PROPN nsubj
# was AUX ROOT
# a DET det
# bit NOUN attr
# of ADP prep
# a DET det
# flop NOUN pobj
# . PUNCT punct
# The DET det
# problem NOUN nsubj
# I PRON nsubj
# have VERB relcl
# is AUX ROOT
# that SCONJ mark
# they PRON nsubj
# charge VERB ccomp
# $ SYM nmod
# 11.99 NUM dobj
# for ADP prep
# a DET det
# sandwich NOUN pobj
# that PRON nsubj
# is AUX relcl
# no ADV neg
# bigger ADJ acomp
# than ADP prep
# a DET det
# Subway PROPN compound
# sub NOUN pobj
# ( PUNCT punct
# which PRON nsubj
# offers VERB relcl
# better ADJ amod
# and CCONJ cc
# more ADJ conj
# amount NOUN dobj
# of ADP prep
# vegetables NOUN pobj
# ) PUNCT punct
# . PUNCT punct
# Shrimp- PUNCT npadvmod
# When SCONJ advmod
# I PRON nsubj
# unwrapped VERB advcl
# it PRON dobj
# ( PUNCT punct
# I PRON nsubj
# live VERB ROOT
# only ADV advmod
# 1/2 NUM nummod
# a DET det
# mile NOUN npadvmod
# from ADP prep
# Brushfire PROPN pobj
# ) PUNCT punct
# it PRON nsubj
# was AUX ROOT
# literally ADV advmod
# ice NOUN npadvmod
# cold ADJ acomp
# . PUNCT punct
# It PRON nsubj
# lacked VERB ROOT
# flavor NOUN dobj
# , PUNCT punct
# seemed VERB conj
# undercooked ADJ oprd
# , PUNCT punct
# and CCONJ cc
# dry ADJ conj
# . PUNCT punct
# It PRON nsubj
# really ADV advmod
# is AUX ROOT
# impressive ADJ acomp
# that SCONJ mark
# the DET det
# place NOUN nsubj
# has AUX aux
# n't PART neg
# closed VERB ccomp
# down ADP prt
# . PUNCT punct
# I PRON nsubj
# would AUX aux
# avoid VERB ROOT
# this DET det
# place NOUN dobj
# if SCONJ mark
# you PRON nsubj
# are AUX aux
# staying VERB advcl
# in ADP prep
# the DET det
# Mirage PROPN pobj
# . PUNCT punct
# The DET det
# refried VERB amod
# beans NOUN nsubjpass
# that PRON nsubj
# came VERB relcl
# with ADP prep
# my PRON poss
# meal NOUN nsubjpass
# were AUX auxpass
# dried VERB ROOT
# out ADP prt
# and CCONJ cc
# crusty ADJ conj
# and CCONJ cc
# the DET det
# food NOUN nsubj
# was AUX conj
# bland ADJ acomp
# . PUNCT punct
# Spend VERB ROOT
# your PRON poss
# money NOUN dobj
# and CCONJ cc
# time NOUN conj
# some DET det
# place NOUN dobj
# else ADV advmod
# . PUNCT punct
# A DET det
# lady NOUN nsubj
# at ADP prep
# the DET det
# table NOUN pobj
# next ADV advmod
# to ADP prep
# us PRON pobj
# found VERB ROOT
# a DET det
# live ADJ amod
# green ADJ amod
# caterpillar NOUN dobj
# In ADP prep
# her PRON poss
# salad NOUN pobj
# . PUNCT punct
# the DET det
# presentation NOUN nsubj
# of ADP prep
# the DET det
# food NOUN pobj
# was AUX ROOT
# awful ADJ acomp
# . PUNCT punct
# I PRON nsubj
# ca AUX aux
# n't PART neg
# tell VERB ROOT
# you PRON dobj
# how SCONJ advmod
# disappointed ADJ acomp
# I PRON nsubj
# was AUX ccomp
# . PUNCT punct
# I PRON nsubj
# think VERB ROOT
# food NOUN nsubj
# should AUX aux
# have VERB ccomp
# flavor NOUN dobj
# and CCONJ cc
# texture NOUN conj
# and CCONJ cc
# both PRON nsubj
# were AUX conj
# lacking ADJ acomp
# . PUNCT punct
# Appetite PROPN nsubj
# instantly ADV advmod
# gone VERB ROOT
# . PUNCT punct
# Overall ADV advmod
# I PRON nsubj
# was AUX ROOT
# not PART neg
# impressed ADJ acomp
# and CCONJ cc
# would AUX aux
# not PART neg
# go VERB conj
# back ADV advmod
# . PUNCT punct
# The DET det
# whole ADJ amod
# experience NOUN nsubj
# was AUX ROOT
# underwhelming ADJ acomp
# , PUNCT punct
# and CCONJ cc
# I PRON nsubj
# think VERB conj
# we PRON nsubj
# 'll AUX aux
# just ADV advmod
# go VERB ccomp
# to ADP prep
# Ninja PROPN compound
# Sushi PROPN pobj
# next ADJ amod
# time NOUN npadvmod
# . PUNCT punct
# Then ADV advmod
# , PUNCT punct
# as SCONJ mark
# if SCONJ mark
# I PRON nsubj
# had AUX aux
# n't PART neg
# wasted VERB advcl
# enough ADJ advmod
# of ADP prep
# my PRON poss
# life NOUN pobj
# there ADV advmod
# , PUNCT punct
# they PRON nsubj
# poured VERB ROOT
# salt NOUN dobj
# in ADP prep
# the DET det
# wound NOUN pobj
# by ADP prep
# drawing VERB pcomp
# out ADP prt
# the DET det
# time NOUN dobj
# it PRON nsubj
# took VERB relcl
# to PART aux
# bring VERB advcl
# the DET det
# check NOUN dobj
# . PUNCT punct

# %%
# Clean the dataset using spacy
# Lowering, Tokenization and removing stopwords/punctuation
stopwords = spacy.lang.en.stop_words.STOP_WORDS
tokens = [token.text.lower() for token in doc if token.text.lower() not in stopwords and token.text not in string.punctuation]
print(tokens)
# Out:
# ['wow', '...', 'loved', 'place', 'crust', 'good', 'tasty', 'texture', 'nasty', 'stopped', 'late', 'bank', 'holiday', 'rick', 'steve', 'recommendation', 'loved', 'selection', 'menu', 'great', 'prices', 'getting', 'angry', 'want', 'damn', 'pho', 'honeslty', 'taste', 'fresh', 'potatoes', 'like', 'rubber', 'tell', 'ahead', 'time', 'kept', 'warmer', 'fries', 'great', 'great', 'touch', 'service', 'prompt', 'cashier', 'care', 'ended', 'wayyy', 'overpriced', 'tried', 'cape', 'cod', 'ravoli', 'chicken', 'cranberry', '...', 'mmmm', 'disgusted', 'pretty', 'sure', 'human', 'hair', 'shocked', 'signs', 'indicate', 'cash', 'highly', 'recommended', 'waitress', 'little', 'slow', 'service', 'place', 'worth', 'time', 'let', 'vegas', 'like', 'burrittos', 'blah', 'food', 'amazing', 'service', 'cute', 'care', '...', 'interior', 'beautiful', 'performed', 'right', '....', 'red', 'velvet', 'cake', '.....', 'ohhh', 'stuff', 'good', 'brought', 'salad', 'asked', 'hole', 'wall', 'great', 'mexican', 'street', 'tacos', 'friendly', 'staff', 'took', 'hour', 'food', '4', 'tables', 'restaurant', 'food', 'luke', 'warm', 'sever', 'running', 'like', 'totally', 'overwhelmed', 'worst', 'salmon', 'sashimi', 'combos', 'like', 'burger', 'fries', 'beer', '23', 'decent', 'deal', 'like', 'final', 'blow', 'found', 'place', 'accident', 'happier', 'like', 'good', 'quick', 'place', 'grab', 'bite', 'familiar', 'pub', 'food', 'favor', 'look', 'overall', 'like', 'place', 'lot', 'redeeming', 'quality', 'restaurant', 'inexpensive', 'ample', 'portions', 'good', 'prices', 'poor', 'service', 'waiter', 'feel', 'like', 'stupid', 'time', 'came', 'table', 'visit', 'hiro', 'delight', 'service', 'sucks', 'shrimp', 'tender', 'moist', 'deal', 'good', 'drag', 'establishment', 'hard', 'judge', 'sides', 'good', 'grossed', 'melted', 'styrofoam', 'want', 'eat', 'fear', 'getting', 'sick', 'positive', 'note', 'server', 'attentive', 'provided', 'great', 'service', 'frozen', 'pucks', 'disgust', 'worst', 'people', 'register', 'thing', 'like', 'prime', 'rib', 'dessert', 'section', 'bad', 'food', 'damn', 'generic', 'burger', 'good', 'beef', 'cooked', 'right', 'want', 'sandwich', 'firehouse', 'greek', 'salad', 'greek', 'dressing', 'tasty', 'pita', 'hummus', 'refreshing', 'ordered', 'duck', 'rare', 'pink', 'tender', 'inside', 'nice', 'char', 'outside', 'came', 'running', 'realized', 'husband', 'left', 'sunglasses', 'table', 'chow', 'mein', 'good', 'horrible', 'attitudes', 'customers', 'talk', 'customers', 'enjoy', 'food', 'portion', 'huge', 'loved', '...', 'friendly', 'servers', 'great', 'food', 'wonderful', 'imaginative', 'menu', 'heart', 'attack', 'grill', 'downtown', 'vegas', 'absolutely', 'flat', 'lined', 'excuse', 'restaurant', 'seafood', 'like', '5', 'strings', 'pasta', 'salad', 'right', 'sauce', 'power', 'scallop', 'perfectly', 'cooked', 'ripped', 'banana', 'ripped', 'petrified', 'tasteless', 'think', 'refill', 'water', 'struggle', 'wave', '10', 'minutes', 'place', 'receives', 'stars', 'appetizers', 'cocktails', 'handmade', 'delicious', 'definitely', 'glad', 'found', 'place', 'great', 'food', 'service', 'huge', 'portions', 'military', 'discount', 'great', 'time', 'dos', 'gringos', 'update', '.....', 'went', 'second', 'time', 'amazing', 'got', 'food', 'apparently', 'heard', 'salt', 'batter', 'fish', 'chewy', 'great', 'way', 'finish', 'great', 'deal', 'included', '5', 'tastings', '2', 'drinks', 'jeff', 'went', 'expected', 'good', 'rice', 'time', 'service', 'meh', 'took', '30', 'min', 'milkshake', 'chocolate', 'milk', 'guess', 'known', 'place', 'suck', 'inside', 'excalibur', 'use', 'common', 'sense', 'scallop', 'dish', 'appalling', 'value', '2', 'times', 'bad', 'customer', 'service', 'sweet', 'potato', 'fries', 'good', 'seasoned', 'today', 'second', 'time', 'lunch', 'buffet', 'pretty', 'good', 'good', 'food', 'vegas', 'feel', 'cheated', 'wasting', 'eating', 'opportunity', 'going', 'rice', 'company', 'coming', 'like', 'experiencing', 'underwhelming', 'relationship', 'parties', 'wait', 'person', 'ask',  ...

# %%
# Word frequency calculation
word_frequency = {}
for token in tokens:
    if token in word_frequency:
        word_frequency[token] += 1
    else:
        word_frequency[token] = 1

# Normalization by dividing with max frequency
max_frequency = max(word_frequency.values())
normalized_frequency = {word: freq / max_frequency for word, freq in word_frequency.items()}

# Sentence tokenization and scoring
sentences = [sent.text for sent in doc.sents]
sentence_scores = {}
for sentence in sentences:
    words = [token.text.lower() for token in nlp(sentence) if token.text.lower() not in stopwords and token.text not in string.punctuation]
    score = sum(normalized_frequency[word] for word in words)
    sentence_scores[sentence] = score

print("Tokens:", tokens)
print("Word Frequency:", word_frequency)
print("Normalized Frequency:", normalized_frequency)
print("Sentence Scores:", sentence_scores)
# Out:
# Tokens: ['wow', '...', 'loved', 'place', 'crust', 'good', 'tasty', 'texture', 'nasty', 'stopped', 'late', 'bank', 'holiday', 'rick', 'steve', 'recommendation', 'loved', 'selection', 'menu', 'great', 'prices', 'getting', 'angry', 'want', 'damn', 'pho', 'honeslty', 'taste', 'fresh', 'potatoes', 'like', 'rubber', 'tell', 'ahead', 'time', 'kept', 'warmer', 'fries', 'great', 'great', 'touch', 'service', 'prompt', 'cashier', 'care', 'ended', 'wayyy', 'overpriced', 'tried', 'cape', 'cod', 'ravoli', 'chicken', 'cranberry', '...', 'mmmm', 'disgusted', 'pretty', 'sure', 'human', 'hair', 'shocked', 'signs', 'indicate', 'cash', 'highly', 'recommended', 'waitress', 'little', 'slow', 'service', 'place', 'worth', 'time', 'let', 'vegas', 'like', 'burrittos', 'blah', 'food', 'amazing', 'service', 'cute', 'care', '...', 'interior', 'beautiful', 'performed', 'right', '....', 'red', 'velvet', 'cake', '.....', 'ohhh', 'stuff', 'good', 'brought', 'salad', 'asked', 'hole', 'wall', 'great', 'mexican', 'street', 'tacos', 'friendly', 'staff', 'took', 'hour', 'food', '4', 'tables', 'restaurant', 'food', 'luke', 'warm', 'sever', 'running', 'like', 'totally', 'overwhelmed', 'worst', 'salmon', 'sashimi', 'combos', 'like', 'burger', 'fries', 'beer', '23', 'decent', 'deal', 'like', 'final', 'blow', 'found', 'place', 'accident', 'happier', 'like', 'good', 'quick', 'place', 'grab', 'bite', 'familiar', 'pub', 'food', 'favor', 'look', 'overall', 'like', 'place', 'lot', 'redeeming', 'quality', 'restaurant', 'inexpensive', 'ample', 'portions', 'good', 'prices', 'poor', 'service', 'waiter', 'feel', 'like', 'stupid', 'time', 'came', 'table', 'visit', 'hiro', 'delight', 'service', 'sucks', 'shrimp', 'tender', 'moist', 'deal', 'good', 'drag', 'establishment', 'hard', 'judge', 'sides', 'good', 'grossed', 'melted', 'styrofoam', 'want', 'eat', 'fear', 'getting', 'sick', 'positive', 'note', 'server', 'attentive', 'provided', 'great', 'service', 'frozen', 'pucks', 'disgust', 'worst', 'people', 'register', 'thing', 'like', 'prime', 'rib', 'dessert', 'section', 'bad', 'food', 'damn', 'generic', 'burger', 'good', 'beef', 'cooked', 'right', 'want', 'sandwich', 'firehouse', 'greek', 'salad', 'greek', 'dressing', 'tasty', 'pita', 'hummus', 'refreshing', 'ordered', 'duck', 'rare', 'pink', 'tender', 'inside', 'nice', 'char', 'outside', 'came', 'running', 'realized', 'husband', 'left', 'sunglasses', 'table', 'chow', 'mein', 'good', 'horrible', 'attitudes', 'customers', 'talk', 'customers', 'enjoy', 'food', 'portion', 'huge', 'loved', '...', 'friendly', 'servers', 'great', 'food', 'wonderful', 'imaginative', 'menu', 'heart', 'attack', 'grill', 'downtown', 'vegas', 'absolutely', 'flat', 'lined', 'excuse', 'restaurant', 'seafood', 'like', '5', 'strings', 'pasta', 'salad', 'right', 'sauce', 'power', 'scallop', 'perfectly', 'cooked', 'ripped', 'banana', 'ripped', 'petrified', 'tasteless', 'think', 'refill', 'water', 'struggle', 'wave', '10', 'minutes', 'place', 'receives', 'stars', 'appetizers', 'cocktails', 'handmade', 'delicious', 'definitely', 'glad', 'found', 'place', 'great', 'food', 'service', 'huge', 'portions', 'military', 'discount', 'great', 'time', 'dos', 'gringos', 'update', '.....', 'went', 'second', 'time', 'amazing', 'got', 'food', 'apparently', 'heard', 'salt', 'batter', 'fish', 'chewy', 'great', 'way', 'finish', 'great', 'deal', 'included', '5', 'tastings', '2', 'drinks', 'jeff', 'went', 'expected', 'good', 'rice', 'time', 'service', 'meh', 'took', '30', 'min', 'milkshake', 'chocolate', 'milk', 'guess', 'known', 'place', 'suck', 'inside', 'excalibur', 'use', 'common', 'sense', 'scallop', 'dish', 'appalling', 'value', '2', 'times', 'bad', 'customer', 'service', 'sweet', 'potato', 'fries', 'good', 'seasoned', 'today', 'second', 'time', 'lunch', 'buffet', 'pretty', 'good', 'good', 'food', 'vegas', 'feel', 'cheated', 'wasting', 'eating', 'opportunity', 'going', 'rice', 'company', 'coming', 'like', 'experiencing', 'underwhelming', 'relationship', 'parties', 'wait', 'person', ...
# Word Frequency: {'wow': 3, '...': 29, 'loved': 10, 'place': 106, 'crust': 2, 'good': 95, 'tasty': 11, 'texture': 3, 'nasty': 3, 'stopped': 2, 'late': 2, 'bank': 1, 'holiday': 1, 'rick': 1, 'steve': 1, 'recommendation': 3, 'selection': 10, 'menu': 14, 'great': 70, 'prices': 10, 'getting': 8, 'angry': 1, 'want': 13, 'damn': 4, 'pho': 6, 'honeslty': 1, 'taste': 13, 'fresh': 14, 'potatoes': 3, 'like': 46, 'rubber': 1, 'tell': 6, 'ahead': 1, 'time': 42, 'kept': 5, 'warmer': 1, 'fries': 9, 'touch': 2, 'service': 85, 'prompt': 1, 'cashier': 2, 'care': 3, 'ended': 2, 'wayyy': 1, 'overpriced': 7, 'tried': 7, 'cape': 1, 'cod': 1, 'ravoli': 1, 'chicken': 17, 'cranberry': 1, 'mmmm': 2, 'disgusted': 1, 'pretty': 20, 'sure': 8, 'human': 2, 'hair': 2, 'shocked': 1, 'signs': 1, 'indicate': 1, 'cash': 1, 'highly': 4, 'recommended': 3, 'waitress': 8, 'little': 10, 'slow': 11, 'worth': 10, 'let': 3, 'vegas': 22, 'burrittos': 1, 'blah': 1, 'food': 126, 'amazing': 24, 'cute': 2, 'interior': 1, 'beautiful': 3, 'performed': 1, 'right': 9, '....': 5, 'red': 2, 'velvet': 1, 'cake': 1, '.....': 3, 'ohhh': 1, 'stuff': 2, 'brought': 3, 'salad': 15, 'asked': 5, 'hole': 1, 'wall': 3, 'mexican': 2, 'street': 1, 'tacos': 4, 'friendly': 27, 'staff': 19, 'took': 8, 'hour': 6, '4': 3, 'tables': 5, 'restaurant': 25, 'luke': 1, 'warm': 7, 'sever': 1, 'running': 4, 'totally': 3, 'overwhelmed': 2, 'worst': 15, 'salmon': 4, 'sashimi': 3, 'combos': 1, 'burger': 12, 'beer': 8, '23': 1, 'decent': 2, 'deal': 7, 'final': 1, 'blow': 1, 'found': 7, 'accident': 1, 'happier': 1, 'quick': 5, 'grab': 1, 'bite': 2, 'familiar': 2, 'pub': 1, 'favor': 2, 'look': 4, 'overall': 8, 'lot': 7, 'redeeming': 1, 'quality': 14, 'inexpensive': 2, 'ample': 1, 'portions': 5, 'poor': 6, 'waiter': 7, 'feel': 11, 'stupid': 1, 'came': 20, 'table': 9, 'visit': 4, 'hiro': 1, 'delight': 2, 'sucks': 3, 'shrimp': 5, 'tender': 6, 'moist': 3, 'drag': 1, 'establishment': 4, 'hard': 6, 'judge': 2, 'sides': 3, 'grossed': 2, 'melted': 1, 'styrofoam': 1, 'eat': 19, 'fear': 1, 'sick': 5, 'positive': 1, 'note': 2, 'server': 13, 'attentive': 7, 'provided': 1, 'frozen': 3, 'pucks': 1, 'disgust': 1, 'people': 9, 'register': 1, 'thing': 8, 'prime': 1, 'rib': 1, 'dessert': 5, 'section': 1, 'bad': 18, 'generic': 1, 'beef': 5, 'cooked': 7, 'sandwich': 9, 'firehouse': 1, 'greek': 3, 'dressing': 3, 'pita': 3, 'hummus': 3, 'refreshing': 1, 'ordered': 14, 'duck': 3, 'rare': 4, 'pink': 1, 'inside': 7, 'nice': 25, 'char': 2, 'outside': 5, 'realized': 2, 'husband': 4, 'left': 6, 'sunglasses': 1, 'chow': 1, 'mein': 1, 'horrible': 6, 'attitudes': 2, 'customers': 2, 'talk': 5, 'enjoy': 6, 'portion': 2, 'huge': 5, 'servers': 5, 'wonderful': 7, 'imaginative': 1, 'heart': 4, 'attack': 2, 'grill': 2, 'downtown': 2, 'absolutely': 8, 'flat': 3, 'lined': 1, 'excuse': 2, 'seafood': 5, '5': 8, 'strings': 1, 'pasta': 5, 'sauce': 10, 'power': 1, 'scallop': 2, 'perfectly': 3, 'ripped': 2, 'banana': 1, 'petrified': 1, 'tasteless': 5, 'think': 16, 'refill': 2, 'water': 3, 'struggle': 1, 'wave': 1, '10': 5, 'minutes': 19, 'receives': 1, 'stars': 15, 'appetizers': 2, 'cocktails': 1, 'handmade': 1, 'delicious': 23, 'definitely': 19, 'glad': 2, 'military': 1, 'discount': 1, 'dos': 1, 'gringos': 1, 'update': 1, 'went': 13, 'second': 3, 'got': 18, 'apparently': 1, 'heard': 2, 'salt': 3, 'batter': 2, 'fish': 5, 'chewy': 3, 'way': 15, 'finish': 2, 'included': 1, 'tastings': 1, '2': 8, 'drinks': 3, 'jeff': 1, 'expected': 3, 'rice': 4, 'meh': 2, '30': 5, 'min': 2, 'milkshake': 1, 'chocolate': 1, 'milk': 1, 'guess': 3, 'known': 2, 'suck': 2, 'excalibur': 1, 'use': 2, 'common': 1, 'sense': 1, 'dish': 8, 'appalling': 1, 'value': 2, 'times': 13, 'customer': 6, 'sweet': 5, 'potato': 6, 'seasoned': 2, 'today': 4, 'lunch': 10, 'buffet': 11, 'cheated': 1, 'wasting': 2, 'eating': 8, 'opportunity': 2, 'going': 18, 'company': 2, 'coming': 10, 'experiencing': 1, 'underwhelming': 2, 'relationship': 1, 'parties': 1, 'wait': 14, 'person': 2, 'ask': 4, 'break': 2, ' ...
# Normalized Frequency: {'wow': 0.023809523809523808, '...': 0.23015873015873015, 'loved': 0.07936507936507936, 'place': 0.8412698412698413, 'crust': 0.015873015873015872, 'good': 0.753968253968254, 'tasty': 0.0873015873015873, 'texture': 0.023809523809523808, 'nasty': 0.023809523809523808, 'stopped': 0.015873015873015872, 'late': 0.015873015873015872, 'bank': 0.007936507936507936, 'holiday': 0.007936507936507936, 'rick': 0.007936507936507936, 'steve': 0.007936507936507936, 'recommendation': 0.023809523809523808, 'selection': 0.07936507936507936, 'menu': 0.1111111111111111, 'great': 0.5555555555555556, 'prices': 0.07936507936507936, 'getting': 0.06349206349206349, 'angry': 0.007936507936507936, 'want': 0.10317460317460317, 'damn': 0.031746031746031744, 'pho': 0.047619047619047616, 'honeslty': 0.007936507936507936, 'taste': 0.10317460317460317, 'fresh': 0.1111111111111111, 'potatoes': 0.023809523809523808, 'like': 0.36507936507936506, 'rubber': 0.007936507936507936, 'tell': 0.047619047619047616, 'ahead': 0.007936507936507936, 'time': 0.3333333333333333, 'kept': 0.03968253968253968, 'warmer': 0.007936507936507936, 'fries': 0.07142857142857142, 'touch': 0.015873015873015872, 'service': 0.6746031746031746, 'prompt': 0.007936507936507936, 'cashier': 0.015873015873015872, 'care': 0.023809523809523808, 'ended': 0.015873015873015872, 'wayyy': 0.007936507936507936, 'overpriced': 0.05555555555555555, 'tried': 0.05555555555555555, 'cape': 0.007936507936507936, 'cod': 0.007936507936507936, 'ravoli': 0.007936507936507936, 'chicken': 0.1349206349206349, 'cranberry': 0.007936507936507936, 'mmmm': 0.015873015873015872, 'disgusted': 0.007936507936507936, 'pretty': 0.15873015873015872, 'sure': 0.06349206349206349, 'human': 0.015873015873015872, 'hair': 0.015873015873015872, 'shocked': 0.007936507936507936, 'signs': 0.007936507936507936, 'indicate': 0.007936507936507936, 'cash': 0.007936507936507936, 'highly': 0.031746031746031744, 'recommended': 0.023809523809523808, 'waitress': 0.06349206349206349, 'little': 0.07936507936507936, 'slow': 0.0873015873015873, 'worth': 0.07936507936507936, 'let': 0.023809523809523808, 'vegas': 0.1746031746031746, 'burrittos': 0.007936507936507936, 'blah': 0.007936507936507936, 'food': 1.0, 'amazing': 0.19047619047619047, 'cute': 0.015873015873015872, 'interior': 0.007936507936507936, 'beautiful': 0.023809523809523808, 'performed': 0.007936507936507936, 'right': 0.07142857142857142, '....': 0.03968253968253968, 'red': 0.015873015873015872, 'velvet': 0.007936507936507936, 'cake': 0.007936507936507936, '.....': 0.023809523809523808, 'ohhh': 0.007936507936507936, 'stuff': 0.015873015873015872, 'brought': 0.023809523809523808, 'salad': 0.11904761904761904, 'asked': 0.03968253968253968, 'hole': 0.007936507936507936, 'wall': 0.023809523809523808, 'mexican': 0.015873015873015872, 'street': 0.007936507936507936, 'tacos': 0.031746031746031744, 'friendly': 0.21428571428571427, 'staff': 0.15079365079365079, 'took': 0.06349206349206349, 'hour': 0.047619047619047616, '4': 0.023809523809523808, 'tables': 0.03968253968253968, 'restaurant': 0.1984126984126984, 'luke': 0.007936507936507936, 'warm': 0.05555555555555555, 'sever': 0.007936507936507936, 'running': 0.031746031746031744, 'totally': 0.023809523809523808, 'overwhelmed': 0.015873015873015872, 'worst': 0.11904761904761904, 'salmon': 0.031746031746031744, 'sashimi': 0.023809523809523808, 'combos': 0.007936507936507936, 'burger': 0.09523809523809523, 'beer': 0.06349206349206349, '23': 0.007936507936507936, 'decent': 0.015873015873015872, 'deal': 0.05555555555555555, 'final': 0.007936507936507936, 'blow': 0.007936507936507936, 'found': 0.05555555555555555, 'accident': 0.007936507936507936, 'happier': 0.007936507936507936, 'quick': 0.03968253968253968, 'grab': 0.007936507936507936, 'bite': 0.015873015873015872, 'familiar': 0.015873015873015872, 'pub': 0.007936507936507936, 'favor': 0.015873015873015872, 'look': 0.031746031746031744, 'overall': 0.06349206349206349, 'lot': 0.0555555 ...
# Sentence Scores: {'Wow...': 0.25396825396825395, 'Loved this place.': 0.9206349206349207, 'Crust is not good.': 0.7698412698412698, 'Not tasty and the texture was just nasty.': 0.1349206349206349, 'Stopped by during the late May bank holiday off Rick Steve recommendation and loved it.': 0.16666666666666666, 'The selection on the menu was great and so were the prices.': 0.8253968253968254, 'Now I am getting angry and I want my damn pho.': 0.25396825396825395, "Honeslty it didn't taste THAT fresh.)": 0.2222222222222222, 'The potatoes were like rubber and you could tell they had been made up ahead of time being kept under a warmer.': 0.8333333333333331, 'The fries were great too.': 0.626984126984127, 'A great touch.': 0.5714285714285714, 'Service was very prompt.': 0.6825396825396826, 'Would not go back.': 0, 'The cashier had no care what so ever on what I had to say it still ended up being wayyy overpriced.': 0.11904761904761904, 'I tried the Cape Cod ravoli, chicken,with cranberry...mmmm!': 0.4682539682539682, 'I was disgusted because I was pretty sure that was human hair.': 0.26190476190476186, 'I was shocked because no signs indicate cash only.': 0.031746031746031744, 'Highly recommended.': 0.05555555555555555, 'Waitress was a little slow in service.': 0.9047619047619048, 'This place is not worth your time, let alone Vegas.': 1.4523809523809523, 'did not like at all.': 0.36507936507936506, 'The Burrittos Blah!': 0.015873015873015872, 'The food, amazing.': 1.1904761904761905, 'Service is also cute.': 0.6904761904761905, 'I could care less...': 0.25396825396825395, 'The interior is just beautiful.': 0.031746031746031744, 'So they performed.': 0.007936507936507936, "That's right....": 0.1111111111111111, 'the red velvet cake.....ohhh this stuff is so good.': 0.8333333333333333, '- They never brought a salad we asked for.': 0.18253968253968253, 'This hole in the wall has great Mexican street tacos, and friendly staff.': 1.007936507936508, 'Took an hour to get our food only 4 tables in restaurant my food was Luke warm, Our sever was running around like he was totally overwhelmed.': 2.8809523809523805, 'The worst was the salmon sashimi.': 0.1746031746031746, 'Also there are combos like a burger, fries, and beer for 23 which is a decent deal.': 0.6825396825396826, 'This was like the final blow!': 0.38095238095238093, 'I found this place by accident and I could not be happier.': 0.9126984126984127, 'seems like a good quick place to grab a bite of some familiar pub food, but do yourself a favor and look elsewhere.': 3.095238095238095, 'Overall, I like this place a lot.': 1.3253968253968254, 'The only redeeming quality of the restaurant was that it was very inexpensive.': 0.3333333333333333, 'Ample portions and good prices.': 0.8809523809523809, 'Poor service, the waiter made me feel like I was stupid every time he came to the table.': 1.8015873015873016, 'My first visit to Hiro was a delight!': 0.05555555555555555, 'Service sucks.': 0.6984126984126985, 'The shrimp tender and moist.': 0.1111111111111111, 'There is not a deal good enough that would drag me into that establishment again.': 0.8492063492063492, "Hard to judge whether these sides were good because we were grossed out by the melted styrofoam and didn't want to eat it for fear of getting sick.": 1.2380952380952381, 'On a positive note, our server was very attentive and provided great service.': 1.4206349206349207, 'Frozen pucks of disgust, with some of the worst people behind the register.': 0.23809523809523808, 'The only thing I did like was the prime rib and dessert section.': 0.492063492063492, "It's too bad the food is so damn generic.": 1.1825396825396823, 'The burger is good beef, cooked just right.': 1.0158730158730158, 'If you want a sandwich just go to any Firehouse!!!!!': 0.18253968253968253, 'My side Greek salad with the Greek dressing was so tasty, and the pita and hummus was very refreshing.': 0.33333333333333337, 'We ordered the duck rare and it was pink and ten ...

# %%
# 3.Select %30 sentences with maximum score
# (you can use heapq library and nlargest class and pass number of sentences, scores, and sentences as arguments)
import heapq
# Selecting top percentage of sentences with maximum scores
percentage = 30  # Percentage of sentences to select
num_sentences = int(len(sentences) * percentage / 100)
top_sentences = heapq.nlargest(num_sentences, sentence_scores, key=sentence_scores.get)

print("Top Sentences:", top_sentences)
# Out:
# Top Sentences: ['I am far from a sushi connoisseur but I can definitely tell the difference between good food and bad food and this was certainly bad food.', 'Food was good, service was good, Prices were good.', 'Good value, great food, great service.', 'Very good food, great atmosphere.1 Damn good steak.', 'Good food , good service .', 'Great food and great service in a clean and friendly setting.', 'seems like a good quick place to grab a bite of some familiar pub food, but do yourself a favor and look elsewhere.', 'Best service and food ever, Maria our server was so good and friendly she made our day.', 'Took an hour to get our food only 4 tables in restaurant my food was Luke warm, Our sever was running around like he was totally overwhelmed.', 'If you want to wait for mediocre food and downright terrible service, then this is the place for you.', 'The food is very good for your typical bar food.', 'So good I am going to have to review this place twice - once hereas a tribute to the place and once as a tribute to an event held here last night.', 'Good beer & drink selection and good food selection.', 'I was proven dead wrong by this sushi bar, not only because the quality is great, but the service is fast and the food, impeccable.', 'We got sitting fairly fast, but, ended up waiting 40 minutes just to place our order, another 30 minutes before the food arrived.', 'My boyfriend and I came here for the first time on a recent trip to Vegas and could not have been more pleased with the quality of food and service.', 'Def coming back to bowl next time If you want healthy authentic or ethic food, try this place.', 'The food was excellent and service was very good.', 'If you love authentic Mexican food and want a whole bunch of interesting, yet delicious meats to choose from, you need to try this place.', 'Service was exceptional and food was a good as all the reviews.', 'Great food and service, huge portions and they give a military discount.', 'Great food and awesome service!', 'There is so much good food in Vegas that I feel cheated for wasting an eating opportunity by going to Rice and Company.', 'Loved it...friendly servers, great food, wonderful and imaginative menu.', 'They have a good selection of food including a massive meatloaf sandwich, a crispy chicken wrap, a delish tuna melt and some tasty burgers.', 'This place is pretty good, nice little vibe in the restaurant.', 'The service was a little slow , considering that were served by 3 people servers so the food was coming in a slow pace.', 'Great service and food.', 'Try them in the airport to experience some tasty food and speedy, friendly service.', 'The menu is always changing, food quality is going down & service is extremely slow.', 'Overall, I like there food and the service.', "I just don't know how this place managed to served the blandest food I have ever eaten when they are preparing Indian cuisine.", 'This place is way too overpriced for mediocre food.', "I find wasting food to be despicable, but this just wasn't food.", 'Great steak, great sides, great wine, amazing desserts.', "Hell no will I go back We've have gotten a much better service from the pizza place next door than the services we received from this restaurant.", "The place was fairly clean but the food simply wasn't worth it.", 'The food was delicious, our bartender was attentive and personable AND we got a great deal!', "So don't go there if you are looking for good food...", "We thought you'd have to venture further away to get good sushi, but this place really hit the spot that night.", 'My husband and I ate lunch here and were very disappointed with the food and service.', 'The food was very good and I enjoyed every mouthful, an enjoyable relaxed venue for couples small family groups etc.', "It's close to my house, it's low-key, non-fancy, affordable prices, good food.", 'Update.....went back for a second time and it was still just as amazing We got the food and apparently they have never he ...

# %%
# 4. Get the final summary and check the length of the summary.
# Combine selected top sentences to form the summary
summary = ' '.join(top_sentences)

# Print the summary and its length
print("Summary:", summary)
# Out:
# Summary: I am far from a sushi connoisseur but I can definitely tell the difference between good food and bad food and this was certainly bad food. Food was good, service was good, Prices were good. Good value, great food, great service. Very good food, great atmosphere.1 Damn good steak. Good food , good service . Great food and great service in a clean and friendly setting. seems like a good quick place to grab a bite of some familiar pub food, but do yourself a favor and look elsewhere. Best service and food ever, Maria our server was so good and friendly she made our day. Took an hour to get our food only 4 tables in restaurant my food was Luke warm, Our sever was running around like he was totally overwhelmed. If you want to wait for mediocre food and downright terrible service, then this is the place for you. The food is very good for your typical bar food. So good I am going to have to review this place twice - once hereas a tribute to the place and once as a tribute to an event held here last night. Good beer & drink selection and good food selection. I was proven dead wrong by this sushi bar, not only because the quality is great, but the service is fast and the food, impeccable. We got sitting fairly fast, but, ended up waiting 40 minutes just to place our order, another 30 minutes before the food arrived. My boyfriend and I came here for the first time on a recent trip to Vegas and could not have been more pleased with the quality of food and service. Def coming back to bowl next time If you want healthy authentic or ethic food, try this place. The food was excellent and service was very good. If you love authentic Mexican food and want a whole bunch of interesting, yet delicious meats to choose from, you need to try this place. Service was exceptional and food was a good as all the reviews. Great food and service, huge portions and they give a military discount. Great food and awesome service! There is so much good food in Vegas that I feel cheated for wasting an eating opportunity by going to Rice and Company. Loved it...friendly servers, great food, wonderful and imaginative menu. They have a good selection of food including a massive meatloaf sandwich, a crispy chicken wrap, a delish tuna melt and some tasty burgers. This place is pretty good, nice little vibe in the restaurant. The service was a little slow , considering that were served by 3 people servers so the food was coming in a slow pace. Great service and food. Try them in the airport to experience some tasty food and speedy, friendly service. The menu is always changing, food quality is going down & service is extremely slow. Overall, I like there food and the service. I just don't know how this place managed to served the blandest food I have ever eaten when they are preparing Indian cuisine. This place is way too overpriced for mediocre food. I find wasting food to be despicable, but this just wasn't food. Great steak, great sides, great wine, amazing desserts. Hell no will I go back We've have gotten a much better service from the pizza place next door than the services we received from this restaurant. The place was fairly clean but the food simply wasn't worth it. The food was delicious, our bartender was attentive and personable AND we got a great deal! So don't go there if you are looking for good food... We thought you'd have to venture further away to get good sushi, but this place really hit the spot that night. My husband and I ate lunch here and were very disappointed with the food and service. The food was very good and I enjoyed every mouthful, an enjoyable relaxed venue for couples small family groups etc. It's close to my house, it's low-key, non-fancy, affordable prices, good food. Update.....went back for a second time and it was still just as amazing We got the food and apparently they have never heard of salt and the batter on the fish was chewy. Food was really good and I got full petty fast. The food came out at a good pace. I can ...

# %%
print("Summary Length:", len(summary))
# Out:
# Summary Length: 21345
